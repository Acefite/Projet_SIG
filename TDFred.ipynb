# %% [markdown]
# <a href="https://colab.research.google.com/github/Acefite/Projet_SIG/blob/main/TDFred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Etude des liens entre les naufrages de navires
# Rendu De Charles Champion 086

# %% [markdown]
# Les naufrages font partie intégrante de l’histoire maritime. Qu’ils résultent de conditions météorologiques extrêmes, d’erreurs humaines, de conflits armés ou de défaillances structurelles.
#
# Cette étude vise à analyser un ensemble de données sur les naufrages afin d’identifier les facteurs qui peuvent aggraver le risque ou la gravité de ces événements. Parmi les paramètres explorés figurent notamment le type de navire, les matériaux utilisés pour la construction, la période historique — incluant des moments critiques comme les guerres mondiales — ainsi que d’autres caractéristiques susceptibles d’influencer la survenue ou l’issue d’un naufrage.
#
# L’objectif est ainsi de mieux comprendre les dynamiques derrière ces pertes maritimes et de dégager des tendances pertinentes pour l’analyse historique, technique ou sécuritaire.

# %%
# !pip install geodatasets
# Out:
# Collecting geodatasets
#   Downloading geodatasets-2024.8.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: pooch in /usr/local/lib/python3.12/dist-packages (from geodatasets) (1.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch->geodatasets) (4.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from pooch->geodatasets) (25.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch->geodatasets) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch->geodatasets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch->geodatasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch->geodatasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch->geodatasets) (2025.11.12)
# Downloading geodatasets-2024.8.0-py3-none-any.whl (20 kB)
# Installing collected packages: geodatasets
# Successfully installed geodatasets-2024.8.0

# %% [markdown]
# Connection Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Premières manipulations

# %% [markdown]
# Import du csv

# %%
import pandas as pd

df = pd.read_excel('/content/drive/MyDrive/ULS/CSV_Shipwreck_Database_120924_SR.csv.xlsx')

df.head()
# Out:
#      SHIPS NAME     AKA SHIPS OWNER VESSEL TYPE YEAR BUILT WHERE BUILT  \
# 0          74 H  120924         NaN        Scow        NaN         NaN
# 1    A B Crosby     NaN         NaN    Schooner       1884         NaN
# 2   A B Sherman     NaN         NaN    Schooner       1883         NaN
# 3  A B Thompson     NaN         NaN       Yacht        NaN         NaN
# 4    A C Austin     NaN         NaN    Schooner        NaN         NaN
#
#    DATE LOST    YEAR MNTH  DAY  ... NUM PASS LIVES LOST SHIP VALUE  \
# 0  7/28/1916  1916.0    7   28  ...      NaN          0        NaN
# 1  3/12/1888  1888.0    3   12  ...      NaN          0        NaN
# 2  12/8/1886  1886.0   12    8  ...      NaN        NaN        NaN
# 3  7/18/1874  1874.0    7   18  ...        7          5        NaN
# 4     2/1868  1868.0    2  NaN  ...      NaN        NaN      30000
#
#   CARGO VALUE NATURE OF CARGO USLSS STATION NAME  MAP LOST PHOTO ON FILE  \
# 0         NaN             NaN      USCG #97 & 99  NaN  NaN             N
# 1         NaN        Coconuts                NaN    N    N             N
# 2         NaN             NaN                NaN  NaN  NaN             Y
# 3         NaN             NaN                NaN  NaN  NaN             N
# 4         NaN            Coal                NaN  NaN  NaN             N
#
#                      MISC INFORMATION
# 0                                 NaN
# 1  Refloated; Made New York 3/26/1888
# 2                             #106238
# 3                                 NaN
# 4                                 NaN
#
# [5 rows x 36 columns]

# %%
df.shape
# Out:
# (4600, 36)

# %% [markdown]
# On retire les navires sur lesquels on a pas d'informations sur la latitude et la longitude.

# %%
df.columns
# On vérifie le nom des colonnes latitudes et longitudes
# Out:
# Index(['SHIPS NAME', 'AKA', 'SHIPS OWNER', 'VESSEL TYPE', 'YEAR BUILT',
#        'WHERE BUILT', 'DATE LOST', 'YEAR', 'MNTH', 'DAY', 'LOCATION LOST',
#        'LATITUDE', 'LONGITUDE', 'CAUSE OF LOSS', 'CONSTRUCTION', 'FLAG',
#        'LENGTH', 'BEAM', 'DRAFT', 'GROSS TONNAGE', 'NET TONNAGE',
#        'HOME HAILING PORT', 'DEPARTURE PORT', 'DESTINATION PORT', 'MASTER',
#        'NUM CREW', 'NUM PASS', 'LIVES LOST', 'SHIP VALUE', 'CARGO VALUE',
#        'NATURE OF CARGO', 'USLSS STATION NAME', 'MAP', 'LOST', 'PHOTO ON FILE',
#        'MISC INFORMATION'],
#       dtype='object')

# %%
df = df.dropna(subset=['LATITUDE', 'LONGITUDE'])
df.head()
# Out:
#      SHIPS NAME                  AKA  SHIPS OWNER     VESSEL TYPE YEAR BUILT  \
# 21  A M C Smith                  NaN          NaN        Schooner        NaN
# 26  A T Coleman  A J Coleman; Sallie          NaN        Schooner       1865
# 39     Aberdeen                  NaN    S H Mills            Bark       1856
# 40  Abiel Abbot                  NaN  Abiel Abbot            Bark       1874
# 46        Acara                  NaN     J M Wood  Screw schooner       1898
#
#            WHERE BUILT   DATE LOST    YEAR MNTH DAY  ... NUM PASS LIVES LOST  \
# 21                 NaN  10/13/1876  1876.0   10  13  ...      NaN          0
# 26     Talbot City, MD   1/20/1901  1901.0    1  20  ...        0          0
# 39       Searsport, ME    1/6/1885  1885.0    1   6  ...        0          0
# 40          Boston, MA   1/20/1903  1903.0    1  20  ...        0          5
# 46  Newcastle, England    3/1/1902  1902.0    3   1  ...        1          0
#
#    SHIP VALUE CARGO VALUE          NATURE OF CARGO  \
# 21       4000         NaN                      NaN
# 26       1800         800                   Lumber
# 39       7000       38000                   Cotton
# 40       8000        3000                   Salt
# 46        NaN      600000  Tin Ingots, tea, spices
#
#                           USLSS STATION NAME MAP LOST PHOTO ON FILE  \
# 21                          Green Island #12   A    N             N
# 26                             Atlantic City   A    Y             N
# 39  Harvey Cedars, Loveladies, & Ship Bottom   A    Y            N
# 40           Long Beach Island & Ship Bottom   A    Y             N
# 46                                       NaN   A    Y             Y
#
#                       MISC INFORMATION
# 21  #1711; Most reports say total loss
# 26                  #22033; Total loss
# 39                    #218; Total loss
# 40                 #105479; Total loss
# 46      Broke up in 3 days; Total loss
#
# [5 rows x 36 columns]

# %%
df.shape
# Out:
# (739, 36)

# %% [markdown]
# On travaille maintenant avec 739 navires dont on connait la position géographique du naufrages à la place de travailler avec 4600 navires. Un autre avantage est que ça allège la base de données et les calculs devraient être plus rapide.

# %% [markdown]
# On vérifie le type des colonnes latitudes et longitudes

# %%
df[['LATITUDE', 'LONGITUDE']].dtypes
# Out:
# LATITUDE     object
# LONGITUDE    object
# dtype: object

# %% [markdown]
# Ils sont de type objets il faut donc les convertir au format numérique pour éviter que ça pose problème par la suite.

# %%
df['LATITUDE'] = pd.to_numeric(df['LATITUDE'], errors='coerce')
df['LONGITUDE'] = pd.to_numeric(df['LONGITUDE'], errors='coerce')

# %% [markdown]
# On supprime les lignes où la conversion entraine des coordonnées non valides (par exemple NaN)

# %%
df = df.dropna(subset=['LATITUDE', 'LONGITUDE'])

# %%
print(df[['LATITUDE', 'LONGITUDE']].dtypes)
print(df.shape)
# Out:
# LATITUDE     float64
# LONGITUDE    float64
# dtype: object
# (714, 36)

# %% [markdown]
# # Création d'intervalles de temps pour l'étude

# %% [markdown]
# Pour l'étude et suivre l'évolution des facteurs aggravant lors des naufrages au cours du temps, on va créer des intervalles de 25 ans qui commencent en 1900.

# %% [markdown]
# Parmis les causes de naufrages, on peut observer des navires qui ont été torpillés, probablement à cause des guerres. Il est donc intéressant de rajouter des intervalles pour les deux guerres mondiales pour vérifier ce fait.

# %%
df['DATE LOST'] = pd.to_datetime(df['DATE LOST'], format='%d/%m/%Y', errors='coerce') # On précise le format des dates
df['YEAR'] = df['DATE LOST'].dt.year
df = df.dropna(subset=['YEAR'])
df['YEAR'] = df['YEAR'].astype(int)
# Tout d'abord on vérifie qu'il ne manque pas de date et on prend les années

# %%
def get_period(y):
    # Périodes des guerres
    if 1914 <= y <= 1918:
        return "WWI (1914–1918)"
    if 1939 <= y <= 1945:
        return "WWII (1939–1945)"

    # Périodes générales
    if y < 1900:
        return "Avant 1900"
    elif 1900 <= y < 1925:
        return "1900–1925"
    elif 1925 <= y < 1950:
        return "1925–1950"
    elif 1950 <= y < 1975:
        return "1950–1975"
    elif 1975 <= y < 2000:
        return "1975–2000"
    elif 2000 <= y:
        return "2000–2025"

# %%
df['PERIODE'] = df['YEAR'].apply(get_period)

# %%
df['PERIODE'].value_counts().sort_index()
# Out:
# PERIODE
# 1900–1925            24
# 1925–1950            24
# 1950–1975            18
# 1975–2000             3
# 2000–2025             2
# Avant 1900          127
# WWI (1914–1918)      23
# WWII (1939–1945)     24
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (245, 37)

# %% [markdown]
# On voit que le nombre de lignes diminue encore, cela est dû au fait que le format JJ/MM/AAAA n'est pas appliqué à toute les lignes. On a maintenant des lignes avec un format de date homogène.

# %% [markdown]
# # Analyse par catégories

# %% [markdown]
# On compte les différents classes de navire, les différentes causes de naufrages et le nombre de navires construits avec certains type matériaux (bois, acier...)

# %% [markdown]
# ## Type de Navire

# %%
# On remplace les valeurs manquantes / vides par Unknwon si il y en a
df['VESSEL TYPE'] = df['VESSEL TYPE'].fillna('Unknown')
df['VESSEL TYPE'] = df['VESSEL TYPE'].replace([''], 'Unknown')

# %%
df['VESSEL TYPE'].value_counts()
# Type de navire
# Out:
# VESSEL TYPE
# Schooner                72
# Barge                   18
# Steamship               15
# Sloop                   13
# Bark                    12
# Freighter               10
# Brig                    10
# Schooner - Barge         9
# Schooner 3 masted        8
# Tanker                   5
# Motor vessel diesel      5
# Freighter steam          4
# Sailing ship             4
# Steamer cargo            3
# Passenger cargo ship     3
# Motor vessel             3
# Tug steam                2
# Ship                     2
# Scow                     2
# Large Landing Craft      2
# Passenger liner          2
# Blimp                    2
# Submarine (U boat)       2
# Tanker steam             2
# Pilot boat               1
# Steamer Concrete         1
# Screw schooner           1
# Frigate                  1
# Sloop - Yacht            1
# Coal barge               1
# Transport steam          1
# Transport                1
# Clam boat                1
# Packet ship              1
# Sloop / unrigged         1
# Fishing boat diesel      1
# Steamer 5 masted         1
# Freighter Liberty        1
# Pilot schooner           1
# Unknown                  1
# Revenue Cutter           1
# Fishing boat             1
# Yarder 3 skysail         1
# Passenger freighter      1
# Clipper ship             1
# Lighter                  1
# Comm Fishing Vessel      1
# Gunboat steam            1
# Sloop - packet ship      1
# Submarine Chaser         1
# Submarine                1
# Troop transport          1
# Tug                      1
# Destroyer                1
# Ferry boat/barge         1
# Merchantman              1
# Fishing Vessel           1
# Yacht steam              1
# Oil tanker               1
# Name: count, dtype: int64

# %% [markdown]
# Comme il y a des catégories avec qu'un seul représentant on va les regrouper en une catégorie (autre)

# %%
threshold = 3 # Correspond à un seuil qui est strictement inférieur à 3 (<3)
other = df['VESSEL TYPE'].value_counts()[df['VESSEL TYPE'].value_counts() < threshold].index # On prend les types qui ont moins de 2 représentants
df['VESSEL TYPE'] = df['VESSEL TYPE'].replace(other, 'Other')
df['VESSEL TYPE'].value_counts()
# Out:
# VESSEL TYPE
# Schooner                72
# Other                   51
# Barge                   18
# Steamship               15
# Sloop                   13
# Bark                    12
# Brig                    10
# Freighter               10
# Schooner - Barge         9
# Schooner 3 masted        8
# Motor vessel diesel      5
# Tanker                   5
# Sailing ship             4
# Freighter steam          4
# Passenger cargo ship     3
# Steamer cargo            3
# Motor vessel             3
# Name: count, dtype: int64

# %% [markdown]
# ## Matériaux

# %%
# On remplace les valeurs manquantes / vides par Unknown si il y en a
df['CONSTRUCTION'] = df['CONSTRUCTION'].fillna('Unknown')
df['CONSTRUCTION'] = df['CONSTRUCTION'].replace([''], 'Unknown')

# %%
df['CONSTRUCTION'].value_counts()
# Matériaux
# Out:
# CONSTRUCTION
# Unknown       148
# Wood           60
# Steel          30
# Iron            4
# Steel           1
# Oak, cedar      1
# Fiberglass      1
# Name: count, dtype: int64

# %% [markdown]
# Comme il y a des catégories avec qu'un seul représentant on va les regrouper en une catégorie (autre)

# %%
threshold = 3 # Correspond à un seuil qui est strictement inférieur à 3 (<3)
other = df['CONSTRUCTION'].value_counts()[df['CONSTRUCTION'].value_counts() < threshold].index # On prend les types qui ont moins de 2 représentants
df['CONSTRUCTION'] = df['CONSTRUCTION'].replace(other, 'Other')
df['CONSTRUCTION'].value_counts()
# Out:
# CONSTRUCTION
# Unknown    148
# Wood        60
# Steel       30
# Iron         4
# Other        3
# Name: count, dtype: int64

# %% [markdown]
# ## Cause du Naufrage

# %%
# On remplace les valeurs manquantes / vides par Unknwon si il y en a
df['CAUSE OF LOSS'] = df['CAUSE OF LOSS'].fillna('Unknown')
df['CAUSE OF LOSS'] = df['CAUSE OF LOSS'].replace([''], 'Unknown')

# %%
df['CAUSE OF LOSS'].value_counts()
# Cause de naufrage
# Out:
# CAUSE OF LOSS
# Unknown                         64
# Stranded                        46
# Foundered                       17
# Grounded                        15
# Sank                             7
#                                 ..
# Stranded in snow storm           1
# Destroyed by British             1
# Torpedoed by U-103; War loss     1
# Collision w/ "Ardmore"           1
# Collision w/ "Argentina"         1
# Name: count, Length: 70, dtype: int64

# %% [markdown]
# Comme il y a des catégories avec qu'un seul représentant on va les regrouper en une catégorie (autre)

# %%
threshold = 3 # Correspond à un seuil qui est strictement inférieur à 3 (<3)
other = df['CAUSE OF LOSS'].value_counts()[df['CAUSE OF LOSS'].value_counts() < threshold].index # On prend les types qui ont moins de 2 représentants
df['CAUSE OF LOSS'] = df['CAUSE OF LOSS'].replace(other, 'Other')
df['CAUSE OF LOSS'].value_counts()
# Out:
# CAUSE OF LOSS
# Unknown               64
# Other                 61
# Stranded              46
# Foundered             17
# Grounded              15
# Sank                   7
# Wrecked                7
# Stranded in storm      6
# Burned                 6
# Foundered in storm     4
# Stranded in fog        3
# Grounded in gale       3
# Capsized               3
# Wrecked in gale        3
# Name: count, dtype: int64

# %%
df
# Out:
#             SHIPS NAME                   AKA                 SHIPS OWNER  \
# 39            Aberdeen                   NaN                   S H Mills
# 46               Acara                   NaN                    J M Wood
# 52        Ada F Crosby                   NaN         John Baizley & Sons
# 59    Addie P McFadden                   NaN                         NaN
# 79            Adolphus                   NaN              Abel C Robbins
# ...                ...                   ...                         ...
# 4554        Winneconne                   NaN  Ammerican Transatlantic Co
# 4570            Yankee                   NaN          U S Shipping Board
# 4581           YRB - 9                   NaN                         NaN
# 4592           Zetland                   NaN                    C D Snow
# 4598          ZPG - 3W  KE-5; Reliance class                    U S Navy
#
#           VESSEL TYPE YEAR BUILT          WHERE BUILT  DATE LOST  YEAR MNTH  \
# 39               Bark       1856        Searsport, ME 1885-06-01  1885    1
# 46              Other       1898   Newcastle, England 1902-01-03  1902    3
# 52               Bark       1875           Calais, ME 1881-05-10  1881   10
# 59           Schooner       1890             Bath, ME 1894-10-04  1894    4
# 79              Other       1873       Green Cove, NS 1886-04-01  1886    1
# ...               ...        ...                  ...        ...   ...  ...
# 4554        Freighter       1907  Sunderland, England 1918-02-06  1918    6
# 4570  Freighter steam       1890        Cleveland, OH 1919-11-06  1919    6
# 4581            Barge        NaN                  NaN 1956-12-06  1956    6
# 4592             Brig       1872          Nova Scotia 1881-02-11  1881   11
# 4598            Other       1960            Akron, OH 1960-06-07  1960    7
#
#      DAY  ... LIVES LOST  SHIP VALUE  CARGO VALUE          NATURE OF CARGO  \
# 39     6  ...          0        7000        38000                   Cotton
# 46     1  ...          0         NaN       600000  Tin Ingots, tea, spices
# 52     5  ...          1       42000         3500             819 ton Coal
# 59    10  ...          0       14000          300                      Ice
# 79     4  ...          0       15000         5000           Barrels, chalk
# ...   ..  ...        ...         ...          ...                      ...
# 4554   2  ...        NaN         NaN          NaN                      NaN
# 4570  11  ...          0         NaN          NaN                     Coal
# 4581  12  ...        NaN         NaN          NaN                      NaN
# 4592   2  ...          0       10000         5000                     Salt
# 4598   6  ...        NaN         NaN          NaN                      NaN
#
#                             USLSS STATION NAME MAP LOST PHOTO ON FILE  \
# 39    Harvey Cedars, Loveladies, & Ship Bottom   A    Y            N
# 46                                         NaN   A    Y             Y
# 52                                         NaN   F    Y             N
# 59                                  Ocean City   A  NaN             N
# 79                        Lewes; Cape Henlopen   A    Y             N
# ...                                        ...  ..  ...           ...
# 4554                                       NaN   F    Y             Y
# 4570                                       NaN   F    Y             Y
# 4581                                       NaN   A    Y             N
# 4592                  Beasleys #30 & Pecks #31   A    Y             N
# 4598                                       NaN   A    Y             N
#
#                                     MISC INFORMATION          PERIODE
# 39                                  #218; Total loss       Avant 1900
# 46                    Broke up in 3 days; Total loss        1900–1925
# 52    #105648; Total loss; Rescued by Mary C Haskell       Avant 1900
# 59                                           #106750       Avant 1900
# 79                                #66708; Total loss       Avant 1900
# ...                                              ...              ...
# 4554        #213661; Hydro #842; Black Sundaay wreck  WWI (1914–1918)
# 4570                       #86129; Hydro Office #589        1900–1925
# 4581                                             NaN        1950–1975
# 4592                              #66732; Total loss       Avant 1900
# 4598                             Also see "Reliance"        1950–1975
#
# [245 rows x 37 columns]

# %% [markdown]
# # Création de la carte interactive

# %% [markdown]
# ## Séparation par intervalle de temps

# %%
import folium

#On centre la carte là où la plupart des naufrages on eu lieu
m = folium.Map(location=[df['LATITUDE'].mean(), df['LONGITUDE'].mean()], zoom_start=3)

# On récupère les dates existantes (uniques)
periodes = df['PERIODE'].unique()

# Boucle pour créer un layer par période
for periode in periodes:
    layer = folium.FeatureGroup(name=periode)   # un layer = une période

    subset = df[df['PERIODE'] == periode]

    for _, row in subset.iterrows():
        popup_text = (
            f"<b>Nom :</b> {row['SHIPS NAME']}<br>"
            f"<b>Type :</b> {row['VESSEL TYPE']}<br>"
            f"<b>Matériau :</b> {row['CONSTRUCTION']}<br>"
            f"<b>Cause :</b> {row['CAUSE OF LOSS']}"
        )

        folium.CircleMarker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=4,
            popup=popup_text,
            color="blue",
            fill=True,
            fill_opacity=0.7
        ).add_to(layer)

    m.add_child(layer)

# On ajoute le contrôle des layers
folium.LayerControl().add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0161f7b6c48d62c0110dcd0eb0272c88 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0161f7b6c48d62c0110dcd0eb0272c88&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0161f7b6c48d62c0110dcd0eb0272c88 = L.map(
#                 &quot;map_0161f7b6c48d62c0110dcd0eb0272c88&quot;,
#                 {
#                     center: [39.41978384081633, -74.06557666938772],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_20b2b5d4d4a2a42534435d0890a0d2e0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_20b2b5d4d4a2a42534435d0890a0d2e0.addTo(map_0161f7b6c48d62c0110dcd0eb0272c88);
#
#
#             var feature_group_c1317dce376a4828774117e0278c8593 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_e9221f6ecb93eec5c3ebc931408d9caa = L.circleMarker(
#                 [39.67529, -74.14656],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_c1317dce376a4828774117e0278c8593);
#
#
#         var popup_073a58b709833f9d4d82ddc843d0362c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30a279ae6c71a8136aa1236966bc029f = $(`&lt;div id=&quot;html_30a279ae6c71a8136aa1236966bc029f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Nom :&lt;/b&gt; Aberdeen&lt;br&gt;&lt;b&gt;Type :&lt;/b&gt; Bark&lt;br&gt;&lt;b&gt;Matériau :&lt;/b&gt; Wood&lt;br&gt;&lt;b&gt;Cause :&lt;/b&gt; Stranded&lt;/div&gt;`)[0];
#                 popup_073a58b709833f9d4d82ddc843d0362c.setContent(html_30a279ae6c71a8136aa1236966bc029f);
#
#
#
#         circle_marker_e9221f6ecb93eec5c3ebc931408d9caa.bindPopup(popup_073a58b709833f9d4d82ddc843d0362c)
#         ;
#
#
#
#
#             var circle_marker_aea0f615841c7b17984d09f614f4593d = L.circleMarker(
#                 [37.5, -72.3333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_c1317dce376a4828774117e0278c8593);
#
#
#         var popup_4004b4b03fb10c0ba174f70ee9cd10f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0789a39a211928a3909d50f9632267f8 = $(`&lt;div id=&quot;html_0789a39a211928a3909d50f9632267f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Nom :&lt;/b&gt; Ada F Crosby&lt;br&gt;&lt;b&gt;Type :&lt;/b&gt; Bark&lt;br&gt;&lt;b&gt;Matériau :&lt;/b&gt; Wood&lt;br&gt;&lt;b&gt;Cause :&lt;/b&gt; Other&lt;/div&gt;`)[0];
#                 popup_4004b4b03fb10c0ba174f70ee9cd10f7.setContent(html_0789a39a211928a3909d50f9632267f8);
#
#
#
#         circle_marker_aea0f615841c7b17984d09f614f4593d.bindPopup(popup_4004b4b03fb10c0ba174f70ee9cd10f7)
#         ;
#
#
#
#
#             var circle_marker_40e65ae32bef1c6d2b0fea8b92d63100 = L.circleMarker(
#                 [39.2874, -74.5506],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_c1317dce376a4828774117e0278c8593);
#
#
#         var popup_2a3b71784d8839d76e22787c0c0cb0d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e726d5d40975a1b5bcc4515d0f3b42f3 = $(`&lt;div id=&quot;html

# %% [markdown]
# On observe que l'ensemble des naufrages recensés avec une date et une localisation connues sont situés dans le long de l'Etat du New Jersey. Cela peut être dû au fait que le museum d'où provient le dataset se situe dans le même état. Donc ils ont sûrement plus d'informations précises sur les naufrages à proximité.

# %%
m.save("carte_date.html")

# %% [markdown]
# ## Rajout des catégories

# %% [markdown]
# Le code est identique pour toute les périodes il y a juste les dates qui changent.

# %% [markdown]
# On va créer une carte avec les layers des catégories (causes de naufrages, matériaux et types de navires) pour chaque période qu'on a déterminées.

# %%
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors

# %% [markdown]
# ## Avant 1900

# %%
# On sélectionne les dates
periode = "Avant 1900"
df_periode = df[df["PERIODE"] == periode].copy()

# On définit les catégories qu'on voudra afficher dans les différents layers
categories = {
    "Materials (CONSTRUCTION)": "CONSTRUCTION",
    "Ship Type (VESSEL TYPE)": "VESSEL TYPE",
    "Cause of Loss": "CAUSE OF LOSS"
}


m_avant_1900 = folium.Map(
    location=[df_periode["LATITUDE"].mean(), df_periode["LONGITUDE"].mean()],
    zoom_start=4
)

# On crée les couleurs qui seront utilisées dans la légende
def make_color_dict(values):
    unique_vals = sorted(values.unique())
    cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
    return {cat: colors.rgb2hex(cmap(i)) for i, cat in enumerate(unique_vals)}


legends = ""

# On crée les layers et les légendes
for layer_name, col in categories.items():

    layer = folium.FeatureGroup(name=layer_name, show=False)

    color_dict = make_color_dict(df_periode[col])

    # On ajoute les points selon les coordonnées
    for _, row in df_periode.iterrows():
        color = color_dict[row[col]]
        folium.CircleMarker(
            location=[row["LATITUDE"], row["LONGITUDE"]],
            radius=4,
            popup=f"<b>{row['SHIPS NAME']}</b><br>{col}: {row[col]}",
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=0.7
        ).add_to(layer)

    m_avant_1900.add_child(layer)

    # On crée la légende dans une boîte en bas à gauche de la carte (c'est en html)
    legend_html = f"""
    <div id="legend_{layer_name.replace(' ', '_')}"
         style="display:none;
                position: fixed;
                bottom: 30px;
                left: 30px;
                z-index:9999;
                background-color: white;
                border:2px solid grey;
                padding:10px;
                font-size:13px;">
    <b>{layer_name}</b><br>
    """

    for cat, col_hex in color_dict.items():
        legend_html += f"""
        <i style="background:{col_hex};
                  width:12px;height:12px;
                  float:left;margin-right:6px;"></i>{cat}<br>
        """

    legend_html += "</div>"
    legends += legend_html

# Ajouter les légendes à la carte
m_avant_1900.get_root().html.add_child(folium.Element(legends))

# Script pour que ce soit la bonne légende qui s'affiche en fonction du layer
# le script est en java (ça marche car folium se base sur leaflet qui est une bibliothèque de java)
js = """
<script>

function hideLegends() {
    document.querySelectorAll('[id^=legend_]').forEach(el => {
        el.style.display = "none";
    });
}

// Exécuter au chargement
hideLegends();

// Intercepter les clics dans le LayerControl
document.addEventListener("change", function(e) {
    if (e.target.classList.contains("leaflet-control-layers-selector")) {

        hideLegends();

        if (e.target.checked) {
            // retrouver le nom du layer dans le label voisin
            let label = e.target.nextSibling.innerText.trim();
            let id = "legend_" + label.replaceAll(" ", "_");
            let legendEl = document.getElementById(id);
            if (legendEl) { legendEl.style.display = "block"; }
        }
    }
});

</script>
"""

m_avant_1900.get_root().html.add_child(folium.Element(js))

# Ajouter LayerControl
folium.LayerControl().add_to(m_avant_1900)

m_avant_1900
# Out:
# /tmp/ipython-input-4270516250.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# /tmp/ipython-input-4270516250.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# /tmp/ipython-input-4270516250.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_414c22e75333516fcb525bcd46cd437d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&quot;legend_Materials_(CONSTRUCTION)&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Materials (CONSTRUCTION)&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Iron&lt;br&gt;
#
#         &lt;i style=&quot;background:#98df8a;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Other&lt;br&gt;
#
#         &lt;i style=&quot;background:#8c564b;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Steel&lt;br&gt;
#
#         &lt;i style=&quot;background:#c7c7c7;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Unknown&lt;br&gt;
#
#         &lt;i style=&quot;background:#9edae5;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Wood&lt;br&gt;
#         &lt;/div&gt;
#     &lt;div id=&quot;legend_Ship_Type_(VESSEL_TYPE)&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Ship Type (VESSEL TYPE)&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Bark&lt;br&gt;
#
#         &lt;i style=&quot;background:#ff7f0e;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Brig&lt;br&gt;
#
#         &lt;i style=&quot;background:#98df8a;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Freighter steam&lt;br&gt;
#
#         &lt;i style=&quot;background:#ff9896;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Other&lt;br&gt;
#
#         &lt;i style=&quot;background:#8c564b;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Sailing ship&lt;br&gt;
#
#         &lt;i style=&quot;background:#e377c2;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Schooner&lt;br&gt;
#
#         &lt;i style=&quot;background:#c7c7c7;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Schooner 3 masted&lt;br&gt;
#
#         &lt;i style=&quot;background:#dbdb8d;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Sloop&lt;br&gt;
#
#         &lt;i style=&quot;background:#9edae5;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Steamship&lt;br&gt;
#         &lt;/div&gt;
#     &lt;div id=&quot;legend_Cause_of_Loss&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Cause of Loss&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Burned&lt;br&gt;
#
#         &lt;i style=&quot;background:#aec7e8;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Capsized&lt;br&gt;
#
#         &lt;i style=&quot;background:#ffbb78;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Foundered&lt;br&gt;
#
#         &lt;i style=&quot;background:#2ca02c;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Foundered in storm&lt;br&gt;
#
#         &lt;i style=&quot;background:#d62728;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Grounded&lt;br&gt;
#
#         &lt;i style=&quot;background:#ff9896;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Grounded in gale&lt;br&gt;
#
#         &lt;i style=&quot;background:#c5b0d5;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Other&lt;br&gt;
#
#         &lt;i style=&quot;background:#8c564b;
#                   width:12p

# %%
m_avant_1900.save("carte_avant_1900.html")

# %% [markdown]
# ## 1900-1925

# %%
# On sélectionne les dates
periode = "1900–1925"
df_periode = df[df["PERIODE"] == periode].copy()

# On définit les catégories qu'on voudra afficher dans les différents layers
categories = {
    "Materials (CONSTRUCTION)": "CONSTRUCTION",
    "Ship Type (VESSEL TYPE)": "VESSEL TYPE",
    "Cause of Loss": "CAUSE OF LOSS"
}


m_1900_1925 = folium.Map(
    location=[df_periode["LATITUDE"].mean(), df_periode["LONGITUDE"].mean()],
    zoom_start=4
)

# On crée les couleurs qui seront utilisées dans la légende
def make_color_dict(values):
    unique_vals = sorted(values.unique())
    cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
    return {cat: colors.rgb2hex(cmap(i)) for i, cat in enumerate(unique_vals)}


legends = ""

# On crée les layers et les légendes
for layer_name, col in categories.items():

    layer = folium.FeatureGroup(name=layer_name, show=False)

    color_dict = make_color_dict(df_periode[col])

    # On ajoute les points selon les coordonnées
    for _, row in df_periode.iterrows():
        color = color_dict[row[col]]
        folium.CircleMarker(
            location=[row["LATITUDE"], row["LONGITUDE"]],
            radius=4,
            popup=f"<b>{row['SHIPS NAME']}</b><br>{col}: {row[col]}",
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=0.7
        ).add_to(layer)

    m_1900_1925.add_child(layer)

    # On crée la légende dans une boîte en bas à gauche de la carte (c'est en html)
    legend_html = f"""
    <div id="legend_{layer_name.replace(' ', '_')}"
         style="display:none;
                position: fixed;
                bottom: 30px;
                left: 30px;
                z-index:9999;
                background-color: white;
                border:2px solid grey;
                padding:10px;
                font-size:13px;">
    <b>{layer_name}</b><br>
    """

    for cat, col_hex in color_dict.items():
        legend_html += f"""
        <i style="background:{col_hex};
                  width:12px;height:12px;
                  float:left;margin-right:6px;"></i>{cat}<br>
        """

    legend_html += "</div>"
    legends += legend_html

# Ajouter les légendes à la carte
m_1900_1925.get_root().html.add_child(folium.Element(legends))

# Script pour que ce soit la bonne légende qui s'affiche en fonction du layer
# le script est en java (ça marche car folium se base sur leaflet qui est une bibliothèque de java)
js = """
<script>

function hideLegends() {
    document.querySelectorAll('[id^=legend_]').forEach(el => {
        el.style.display = "none";
    });
}

// Exécuter au chargement
hideLegends();

// Intercepter les clics dans le LayerControl
document.addEventListener("change", function(e) {
    if (e.target.classList.contains("leaflet-control-layers-selector")) {

        hideLegends();

        if (e.target.checked) {
            // retrouver le nom du layer dans le label voisin
            let label = e.target.nextSibling.innerText.trim();
            let id = "legend_" + label.replaceAll(" ", "_");
            let legendEl = document.getElementById(id);
            if (legendEl) { legendEl.style.display = "block"; }
        }
    }
});

</script>
"""

m_1900_1925.get_root().html.add_child(folium.Element(js))

# Ajouter LayerControl
folium.LayerControl().add_to(m_1900_1925)

m_1900_1925
# Out:
# /tmp/ipython-input-61846726.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# /tmp/ipython-input-61846726.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# /tmp/ipython-input-61846726.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7f40535ad56bb66e25e27a1d9e5bd103 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&quot;legend_Materials_(CONSTRUCTION)&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Materials (CONSTRUCTION)&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Iron&lt;br&gt;
#
#         &lt;i style=&quot;background:#d62728;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Steel&lt;br&gt;
#
#         &lt;i style=&quot;background:#f7b6d2;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Unknown&lt;br&gt;
#
#         &lt;i style=&quot;background:#9edae5;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Wood&lt;br&gt;
#         &lt;/div&gt;
#     &lt;div id=&quot;legend_Ship_Type_(VESSEL_TYPE)&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Ship Type (VESSEL TYPE)&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Barge&lt;br&gt;
#
#         &lt;i style=&quot;background:#ff7f0e;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Freighter steam&lt;br&gt;
#
#         &lt;i style=&quot;background:#98df8a;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Other&lt;br&gt;
#
#         &lt;i style=&quot;background:#ff9896;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Schooner&lt;br&gt;
#
#         &lt;i style=&quot;background:#8c564b;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Schooner - Barge&lt;br&gt;
#
#         &lt;i style=&quot;background:#e377c2;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Schooner 3 masted&lt;br&gt;
#
#         &lt;i style=&quot;background:#c7c7c7;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Sloop&lt;br&gt;
#
#         &lt;i style=&quot;background:#dbdb8d;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Steamer cargo &lt;br&gt;
#
#         &lt;i style=&quot;background:#9edae5;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Steamship&lt;br&gt;
#         &lt;/div&gt;
#     &lt;div id=&quot;legend_Cause_of_Loss&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Cause of Loss&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Foundered&lt;br&gt;
#
#         &lt;i style=&quot;background:#ff7f0e;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Grounded&lt;br&gt;
#
#         &lt;i style=&quot;background:#98df8a;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Other&lt;br&gt;
#
#         &lt;i style=&quot;background:#9467bd;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Sank&lt;br&gt;
#
#         &lt;i style=&quot;background:#c49c94;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Stranded&lt;br&gt;
#
#         &lt;i style=&quot;background:#7f7f7f;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Stranded in storm&lt;br&gt;
#
#         &lt;i style=&quot;background:#dbdb8d;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Unknown&lt;br&gt;
#
#         &lt;i style=&quot;background:#9edae5;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Wrecked&lt;br&gt;
#         &lt;/div&gt;
#
# &lt;script&gt;
#
# function hideLegends() {
#     docume

# %%
m_1900_1925.save("carte_1900_1925.html")

# %% [markdown]
# ## 1925-1950

# %%
# On sélectionne les dates
periode = "1925–1950"
df_periode = df[df["PERIODE"] == periode].copy()

# On définit les catégories qu'on voudra afficher dans les différents layers
categories = {
    "Materials (CONSTRUCTION)": "CONSTRUCTION",
    "Ship Type (VESSEL TYPE)": "VESSEL TYPE",
    "Cause of Loss": "CAUSE OF LOSS"
}


m_1925_1950 = folium.Map(
    location=[df_periode["LATITUDE"].mean(), df_periode["LONGITUDE"].mean()],
    zoom_start=4
)

# On crée les couleurs qui seront utilisées dans la légende
color_dict = make_color_dict(df_periode[col])


legends = ""

# On crée les layers et les légendes
for layer_name, col in categories.items():

    layer = folium.FeatureGroup(name=layer_name, show=False)

    vals = df_periode[col].dropna().unique()
    if len(vals) == 0:
        print(f"Aucune donnée pour {col} dans la période {periode}, on saute ce layer.")
        continue  # saute la catégorie si vide
    color_dict = make_color_dict(df_periode[col].dropna())


    # On ajoute les points selon les coordonnées
    for _, row in df_periode.iterrows():
        color = color_dict[row[col]]
        folium.CircleMarker(
            location=[row["LATITUDE"], row["LONGITUDE"]],
            radius=4,
            popup=f"<b>{row['SHIPS NAME']}</b><br>{col}: {row[col]}",
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=0.7
        ).add_to(layer)

    m_1925_1950.add_child(layer)

    # On crée la légende dans une boîte en bas à gauche de la carte (c'est en html)
    legend_html = f"""
    <div id="legend_{layer_name.replace(' ', '_')}"
         style="display:none;
                position: fixed;
                bottom: 30px;
                left: 30px;
                z-index:9999;
                background-color: white;
                border:2px solid grey;
                padding:10px;
                font-size:13px;">
    <b>{layer_name}</b><br>
    """

    for cat, col_hex in color_dict.items():
        legend_html += f"""
        <i style="background:{col_hex};
                  width:12px;height:12px;
                  float:left;margin-right:6px;"></i>{cat}<br>
        """

    legend_html += "</div>"
    legends += legend_html

# Ajouter les légendes à la carte
m_1925_1950.get_root().html.add_child(folium.Element(legends))

# Script pour que ce soit la bonne légende qui s'affiche en fonction du layer
# le script est en java (ça marche car folium se base sur leaflet qui est une bibliothèque de java)
js = """
<script>

function hideLegends() {
    document.querySelectorAll('[id^=legend_]').forEach(el => {
        el.style.display = "none";
    });
}

// Exécuter au chargement
hideLegends();

// Intercepter les clics dans le LayerControl
document.addEventListener("change", function(e) {
    if (e.target.classList.contains("leaflet-control-layers-selector")) {

        hideLegends();

        if (e.target.checked) {
            // retrouver le nom du layer dans le label voisin
            let label = e.target.nextSibling.innerText.trim();
            let id = "legend_" + label.replaceAll(" ", "_");
            let legendEl = document.getElementById(id);
            if (legendEl) { legendEl.style.display = "block"; }
        }
    }
});

</script>
"""

m_1925_1950.get_root().html.add_child(folium.Element(js))

# Ajouter LayerControl
folium.LayerControl().add_to(m_1925_1950)

m_1925_1950
# Out:
# /tmp/ipython-input-61846726.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# /tmp/ipython-input-61846726.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# /tmp/ipython-input-61846726.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3df60330adc0b05e1a2dafe0a3ff80e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&quot;legend_Materials_(CONSTRUCTION)&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Materials (CONSTRUCTION)&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Iron&lt;br&gt;
#
#         &lt;i style=&quot;background:#98df8a;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Other&lt;br&gt;
#
#         &lt;i style=&quot;background:#8c564b;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Steel&lt;br&gt;
#
#         &lt;i style=&quot;background:#c7c7c7;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Unknown&lt;br&gt;
#
#         &lt;i style=&quot;background:#9edae5;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Wood&lt;br&gt;
#         &lt;/div&gt;
#     &lt;div id=&quot;legend_Ship_Type_(VESSEL_TYPE)&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Ship Type (VESSEL TYPE)&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Barge&lt;br&gt;
#
#         &lt;i style=&quot;background:#ffbb78;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Motor vessel diesel&lt;br&gt;
#
#         &lt;i style=&quot;background:#d62728;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Other&lt;br&gt;
#
#         &lt;i style=&quot;background:#8c564b;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Passenger cargo ship&lt;br&gt;
#
#         &lt;i style=&quot;background:#f7b6d2;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Schooner - Barge&lt;br&gt;
#
#         &lt;i style=&quot;background:#bcbd22;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Schooner 3 masted&lt;br&gt;
#
#         &lt;i style=&quot;background:#9edae5;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Steamship&lt;br&gt;
#         &lt;/div&gt;
#     &lt;div id=&quot;legend_Cause_of_Loss&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Cause of Loss&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Burned&lt;br&gt;
#
#         &lt;i style=&quot;background:#2ca02c;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Foundered&lt;br&gt;
#
#         &lt;i style=&quot;background:#9467bd;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Other&lt;br&gt;
#
#         &lt;i style=&quot;background:#e377c2;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Sank&lt;br&gt;
#
#         &lt;i style=&quot;background:#bcbd22;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Stranded in fog&lt;br&gt;
#
#         &lt;i style=&quot;background:#9edae5;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Unknown&lt;br&gt;
#         &lt;/div&gt;
#
# &lt;script&gt;
#
# function hideLegends() {
#     document.querySelectorAll(&#x27;[id^=legend_]&#x27;).forEach(el =&gt; {
#         el.style.display = &quot;none&quot;;
#     });
# }
#
# // Exécuter au chargement
# hideLegends();
#
# // Intercepter les clics dans le LayerControl
# document.addEventListener(&quot;change&quot;, function(e) {
#     if (e.target.classList.contains(&quot;leaflet-control-layers-selector&quot;)) {
#
#         hideLegends();
#
#         if (e.target.checked) {
#             // retrouver le nom du layer dans le label voisin
#             let label = e.target.nextSibling.innerText.trim();

# %%
m_1925_1950.save("carte_1925_1950.html")

# %% [markdown]
# ## 1950-1975

# %%
# On sélectionne les dates
periode = "1950–1975"
df_periode = df[df["PERIODE"] == periode].copy()

# On définit les catégories qu'on voudra afficher dans les différents layers
categories = {
    "Materials (CONSTRUCTION)": "CONSTRUCTION",
    "Ship Type (VESSEL TYPE)": "VESSEL TYPE",
    "Cause of Loss": "CAUSE OF LOSS"
}


m_1950_1975 = folium.Map(
    location=[df_periode["LATITUDE"].mean(), df_periode["LONGITUDE"].mean()],
    zoom_start=4
)

# On crée les couleurs qui seront utilisées dans la légende
def make_color_dict(values):
    unique_vals = sorted(values.unique())
    cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
    return {cat: colors.rgb2hex(cmap(i)) for i, cat in enumerate(unique_vals)}


legends = ""

# On crée les layers et les légendes
for layer_name, col in categories.items():

    layer = folium.FeatureGroup(name=layer_name, show=False)

    color_dict = make_color_dict(df_periode[col])

    # On ajoute les points selon les coordonnées
    for _, row in df_periode.iterrows():
        color = color_dict[row[col]]
        folium.CircleMarker(
            location=[row["LATITUDE"], row["LONGITUDE"]],
            radius=4,
            popup=f"<b>{row['SHIPS NAME']}</b><br>{col}: {row[col]}",
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=0.7
        ).add_to(layer)

    m_1950_1975.add_child(layer)

    # On crée la légende dans une boîte en bas à gauche de la carte (c'est en html)
    legend_html = f"""
    <div id="legend_{layer_name.replace(' ', '_')}"
         style="display:none;
                position: fixed;
                bottom: 30px;
                left: 30px;
                z-index:9999;
                background-color: white;
                border:2px solid grey;
                padding:10px;
                font-size:13px;">
    <b>{layer_name}</b><br>
    """

    for cat, col_hex in color_dict.items():
        legend_html += f"""
        <i style="background:{col_hex};
                  width:12px;height:12px;
                  float:left;margin-right:6px;"></i>{cat}<br>
        """

    legend_html += "</div>"
    legends += legend_html

# Ajouter les légendes à la carte
m_1950_1975.get_root().html.add_child(folium.Element(legends))

# Script pour que ce soit la bonne légende qui s'affiche en fonction du layer
# le script est en java (ça marche car folium se base sur leaflet qui est une bibliothèque de java)
js = """
<script>

function hideLegends() {
    document.querySelectorAll('[id^=legend_]').forEach(el => {
        el.style.display = "none";
    });
}

// Exécuter au chargement
hideLegends();

// Intercepter les clics dans le LayerControl
document.addEventListener("change", function(e) {
    if (e.target.classList.contains("leaflet-control-layers-selector")) {

        hideLegends();

        if (e.target.checked) {
            // retrouver le nom du layer dans le label voisin
            let label = e.target.nextSibling.innerText.trim();
            let id = "legend_" + label.replaceAll(" ", "_");
            let legendEl = document.getElementById(id);
            if (legendEl) { legendEl.style.display = "block"; }
        }
    }
});

</script>
"""

m_1950_1975.get_root().html.add_child(folium.Element(js))

# Ajouter LayerControl
folium.LayerControl().add_to(m_1950_1975)

m_1950_1975
# Out:
# /tmp/ipython-input-3403423859.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# /tmp/ipython-input-3403423859.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# /tmp/ipython-input-3403423859.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ca9edfa855ef00ee1877f895edece4a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&quot;legend_Materials_(CONSTRUCTION)&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Materials (CONSTRUCTION)&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Steel&lt;br&gt;
#
#         &lt;i style=&quot;background:#8c564b;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Unknown&lt;br&gt;
#
#         &lt;i style=&quot;background:#9edae5;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Wood&lt;br&gt;
#         &lt;/div&gt;
#     &lt;div id=&quot;legend_Ship_Type_(VESSEL_TYPE)&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Ship Type (VESSEL TYPE)&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Barge&lt;br&gt;
#
#         &lt;i style=&quot;background:#ffbb78;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Freighter&lt;br&gt;
#
#         &lt;i style=&quot;background:#d62728;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Motor vessel&lt;br&gt;
#
#         &lt;i style=&quot;background:#8c564b;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Motor vessel diesel&lt;br&gt;
#
#         &lt;i style=&quot;background:#f7b6d2;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Other&lt;br&gt;
#
#         &lt;i style=&quot;background:#bcbd22;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Steamship&lt;br&gt;
#
#         &lt;i style=&quot;background:#9edae5;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Tanker&lt;br&gt;
#         &lt;/div&gt;
#     &lt;div id=&quot;legend_Cause_of_Loss&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Cause of Loss&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Other&lt;br&gt;
#
#         &lt;i style=&quot;background:#d62728;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Stranded&lt;br&gt;
#
#         &lt;i style=&quot;background:#f7b6d2;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Stranded in storm&lt;br&gt;
#
#         &lt;i style=&quot;background:#9edae5;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Unknown&lt;br&gt;
#         &lt;/div&gt;
#
# &lt;script&gt;
#
# function hideLegends() {
#     document.querySelectorAll(&#x27;[id^=legend_]&#x27;).forEach(el =&gt; {
#         el.style.display = &quot;none&quot;;
#     });
# }
#
# // Exécuter au chargement
# hideLegends();
#
# // Intercepter les clics dans le LayerControl
# document.addEventListener(&quot;change&quot;, function(e) {
#     if (e.target.classList.contains(&quot;leaflet-control-layers-selector&quot;)) {
#
#         hideLegends();
#
#         if (e.target.checked) {
#             // retrouver le nom du layer dans le label voisin
#             let label = e.target.nextSibling.innerText.trim();
#             let id = &quot;legend_&quot; + label.replaceAll(&quot; &quot;, &quot;_&quot;);
#             let legendEl = document.getElementById(id);
#             if (legendEl) { legendEl.style.display = &quot;block&quot;; }
#         }
#     }
# });
#
# &lt;/script&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ca9edfa855ef00ee1877f895edece4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ca9edfa855ef00ee1877f895edece4a = L.map(
#                 &quot;map_3ca9edfa855ef00ee1877f895edece4a&quot;,
#                 {
#                     center: [39.33908855555555, -74.41282133333333],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zo

# %%
m_1950_1975.save("carte_1950_1975.html")

# %% [markdown]
# ## 1975-2000

# %%
# On sélectionne les dates
periode = "1975–2000"
df_periode = df[df["PERIODE"] == periode].copy()

# On définit les catégories qu'on voudra afficher dans les différents layers
categories = {
    "Materials (CONSTRUCTION)": "CONSTRUCTION",
    "Ship Type (VESSEL TYPE)": "VESSEL TYPE",
    "Cause of Loss": "CAUSE OF LOSS"
}


m_1975_2000 = folium.Map(
    location=[df_periode["LATITUDE"].mean(), df_periode["LONGITUDE"].mean()],
    zoom_start=4
)

# On crée les couleurs qui seront utilisées dans la légende
def make_color_dict(values):
    unique_vals = sorted(values.unique())
    cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
    return {cat: colors.rgb2hex(cmap(i)) for i, cat in enumerate(unique_vals)}


legends = ""

# On crée les layers et les légendes
for layer_name, col in categories.items():

    layer = folium.FeatureGroup(name=layer_name, show=False)

    color_dict = make_color_dict(df_periode[col])

    # On ajoute les points selon les coordonnées
    for _, row in df_periode.iterrows():
        color = color_dict[row[col]]
        folium.CircleMarker(
            location=[row["LATITUDE"], row["LONGITUDE"]],
            radius=4,
            popup=f"<b>{row['SHIPS NAME']}</b><br>{col}: {row[col]}",
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=0.7
        ).add_to(layer)

    m_1975_2000.add_child(layer)

    # On crée la légende dans une boîte en bas à gauche de la carte (c'est en html)
    legend_html = f"""
    <div id="legend_{layer_name.replace(' ', '_')}"
         style="display:none;
                position: fixed;
                bottom: 30px;
                left: 30px;
                z-index:9999;
                background-color: white;
                border:2px solid grey;
                padding:10px;
                font-size:13px;">
    <b>{layer_name}</b><br>
    """

    for cat, col_hex in color_dict.items():
        legend_html += f"""
        <i style="background:{col_hex};
                  width:12px;height:12px;
                  float:left;margin-right:6px;"></i>{cat}<br>
        """

    legend_html += "</div>"
    legends += legend_html

# Ajouter les légendes à la carte
m_1975_2000.get_root().html.add_child(folium.Element(legends))

# Script pour que ce soit la bonne légende qui s'affiche en fonction du layer
# le script est en java (ça marche car folium se base sur leaflet qui est une bibliothèque de java)
js = """
<script>

function hideLegends() {
    document.querySelectorAll('[id^=legend_]').forEach(el => {
        el.style.display = "none";
    });
}

// Exécuter au chargement
hideLegends();

// Intercepter les clics dans le LayerControl
document.addEventListener("change", function(e) {
    if (e.target.classList.contains("leaflet-control-layers-selector")) {

        hideLegends();

        if (e.target.checked) {
            // retrouver le nom du layer dans le label voisin
            let label = e.target.nextSibling.innerText.trim();
            let id = "legend_" + label.replaceAll(" ", "_");
            let legendEl = document.getElementById(id);
            if (legendEl) { legendEl.style.display = "block"; }
        }
    }
});

</script>
"""

m_1975_2000.get_root().html.add_child(folium.Element(js))

# Ajouter LayerControl
folium.LayerControl().add_to(m_1975_2000)

m_1975_2000
# Out:
# /tmp/ipython-input-4023818934.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# /tmp/ipython-input-4023818934.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# /tmp/ipython-input-4023818934.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27cdb98c730eae31628c0d90db29d709 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&quot;legend_Materials_(CONSTRUCTION)&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Materials (CONSTRUCTION)&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Steel&lt;br&gt;
#         &lt;/div&gt;
#     &lt;div id=&quot;legend_Ship_Type_(VESSEL_TYPE)&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Ship Type (VESSEL TYPE)&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Other&lt;br&gt;
#
#         &lt;i style=&quot;background:#9edae5;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Tanker&lt;br&gt;
#         &lt;/div&gt;
#     &lt;div id=&quot;legend_Cause_of_Loss&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Cause of Loss&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Foundered in storm&lt;br&gt;
#
#         &lt;i style=&quot;background:#9edae5;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Other&lt;br&gt;
#         &lt;/div&gt;
#
# &lt;script&gt;
#
# function hideLegends() {
#     document.querySelectorAll(&#x27;[id^=legend_]&#x27;).forEach(el =&gt; {
#         el.style.display = &quot;none&quot;;
#     });
# }
#
# // Exécuter au chargement
# hideLegends();
#
# // Intercepter les clics dans le LayerControl
# document.addEventListener(&quot;change&quot;, function(e) {
#     if (e.target.classList.contains(&quot;leaflet-control-layers-selector&quot;)) {
#
#         hideLegends();
#
#         if (e.target.checked) {
#             // retrouver le nom du layer dans le label voisin
#             let label = e.target.nextSibling.innerText.trim();
#             let id = &quot;legend_&quot; + label.replaceAll(&quot; &quot;, &quot;_&quot;);
#             let legendEl = document.getElementById(id);
#             if (legendEl) { legendEl.style.display = &quot;block&quot;; }
#         }
#     }
# });
#
# &lt;/script&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27cdb98c730eae31628c0d90db29d709&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27cdb98c730eae31628c0d90db29d709 = L.map(
#                 &quot;map_27cdb98c730eae31628c0d90db29d709&quot;,
#                 {
#                     center: [39.65425333333334, -72.74313333333333],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e433e043d22a31d2f38ef4e9247930a9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e433e043d22a31d2f38ef4e9247930a9.addTo(map_27cdb98c730eae31628c0d90db29d709);
#
#
#             var feature_group_7e1b7adfc837a014e29d6f99aeb3aa45 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_9c31659f39676a79942d89406786676b = L.circleMarker(
#                 [40.13583, -73.72666],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1f77b4&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_7e1b7adfc837a014e29d6f99aeb3aa45);

# %%
m_1975_2000.save("carte_1975_2000.html")

# %% [markdown]
# ## 2000-2025

# %%
# On sélectionne les dates
periode = "2000–2025"
df_periode = df[df["PERIODE"] == periode].copy()

# On définit les catégories qu'on voudra afficher dans les différents layers
categories = {
    "Materials (CONSTRUCTION)": "CONSTRUCTION",
    "Ship Type (VESSEL TYPE)": "VESSEL TYPE",
    "Cause of Loss": "CAUSE OF LOSS"
}


m_2000_2025 = folium.Map(
    location=[df_periode["LATITUDE"].mean(), df_periode["LONGITUDE"].mean()],
    zoom_start=4
)

# On crée les couleurs qui seront utilisées dans la légende
def make_color_dict(values):
    unique_vals = sorted(values.unique())
    cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
    return {cat: colors.rgb2hex(cmap(i)) for i, cat in enumerate(unique_vals)}


legends = ""

# On crée les layers et les légendes
for layer_name, col in categories.items():

    layer = folium.FeatureGroup(name=layer_name, show=False)

    color_dict = make_color_dict(df_periode[col])

    # On ajoute les points selon les coordonnées
    for _, row in df_periode.iterrows():
        color = color_dict[row[col]]
        folium.CircleMarker(
            location=[row["LATITUDE"], row["LONGITUDE"]],
            radius=4,
            popup=f"<b>{row['SHIPS NAME']}</b><br>{col}: {row[col]}",
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=0.7
        ).add_to(layer)

    m_2000_2025.add_child(layer)

    # On crée la légende dans une boîte en bas à gauche de la carte (c'est en html)
    legend_html = f"""
    <div id="legend_{layer_name.replace(' ', '_')}"
         style="display:none;
                position: fixed;
                bottom: 30px;
                left: 30px;
                z-index:9999;
                background-color: white;
                border:2px solid grey;
                padding:10px;
                font-size:13px;">
    <b>{layer_name}</b><br>
    """

    for cat, col_hex in color_dict.items():
        legend_html += f"""
        <i style="background:{col_hex};
                  width:12px;height:12px;
                  float:left;margin-right:6px;"></i>{cat}<br>
        """

    legend_html += "</div>"
    legends += legend_html

# Ajouter les légendes à la carte
m_2000_2025.get_root().html.add_child(folium.Element(legends))

# Script pour que ce soit la bonne légende qui s'affiche en fonction du layer
# le script est en java (ça marche car folium se base sur leaflet qui est une bibliothèque de java)
js = """
<script>

function hideLegends() {
    document.querySelectorAll('[id^=legend_]').forEach(el => {
        el.style.display = "none";
    });
}

// Exécuter au chargement
hideLegends();

// Intercepter les clics dans le LayerControl
document.addEventListener("change", function(e) {
    if (e.target.classList.contains("leaflet-control-layers-selector")) {

        hideLegends();

        if (e.target.checked) {
            // retrouver le nom du layer dans le label voisin
            let label = e.target.nextSibling.innerText.trim();
            let id = "legend_" + label.replaceAll(" ", "_");
            let legendEl = document.getElementById(id);
            if (legendEl) { legendEl.style.display = "block"; }
        }
    }
});

</script>
"""

m_2000_2025.get_root().html.add_child(folium.Element(js))

# Ajouter LayerControl
folium.LayerControl().add_to(m_2000_2025)

m_2000_2025
# Out:
# /tmp/ipython-input-874239417.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# /tmp/ipython-input-874239417.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# /tmp/ipython-input-874239417.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_add262bbbc2a19c73bb51b61a6dcb583 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&quot;legend_Materials_(CONSTRUCTION)&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Materials (CONSTRUCTION)&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Other&lt;br&gt;
#
#         &lt;i style=&quot;background:#9edae5;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Unknown&lt;br&gt;
#         &lt;/div&gt;
#     &lt;div id=&quot;legend_Ship_Type_(VESSEL_TYPE)&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Ship Type (VESSEL TYPE)&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Other&lt;br&gt;
#         &lt;/div&gt;
#     &lt;div id=&quot;legend_Cause_of_Loss&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Cause of Loss&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Burned&lt;br&gt;
#
#         &lt;i style=&quot;background:#9edae5;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Unknown&lt;br&gt;
#         &lt;/div&gt;
#
# &lt;script&gt;
#
# function hideLegends() {
#     document.querySelectorAll(&#x27;[id^=legend_]&#x27;).forEach(el =&gt; {
#         el.style.display = &quot;none&quot;;
#     });
# }
#
# // Exécuter au chargement
# hideLegends();
#
# // Intercepter les clics dans le LayerControl
# document.addEventListener(&quot;change&quot;, function(e) {
#     if (e.target.classList.contains(&quot;leaflet-control-layers-selector&quot;)) {
#
#         hideLegends();
#
#         if (e.target.checked) {
#             // retrouver le nom du layer dans le label voisin
#             let label = e.target.nextSibling.innerText.trim();
#             let id = &quot;legend_&quot; + label.replaceAll(&quot; &quot;, &quot;_&quot;);
#             let legendEl = document.getElementById(id);
#             if (legendEl) { legendEl.style.display = &quot;block&quot;; }
#         }
#     }
# });
#
# &lt;/script&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_add262bbbc2a19c73bb51b61a6dcb583&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_add262bbbc2a19c73bb51b61a6dcb583 = L.map(
#                 &quot;map_add262bbbc2a19c73bb51b61a6dcb583&quot;,
#                 {
#                     center: [39.079635, -73.35263499999999],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c193b623dc7493fbeeeebefb27ffea32 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c193b623dc7493fbeeeebefb27ffea32.addTo(map_add262bbbc2a19c73bb51b61a6dcb583);
#
#
#             var feature_group_3521b8d1bd9e678d5848018ef01368ad = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_fd451b74f5e5f61265526a4d3cba3620 = L.circleMarker(
#                 [39.75733, -73.46194],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1f77b4&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_3521b8d1bd9e678d5848018ef01368ad);

# %%
m_2000_2025.save("carte_2000_2025.html")

# %% [markdown]
# ## WWI

# %%
# On sélectionne les dates
periode = "WWI (1914–1918)"
df_periode = df[df["PERIODE"] == periode].copy()

# On définit les catégories qu'on voudra afficher dans les différents layers
categories = {
    "Materials (CONSTRUCTION)": "CONSTRUCTION",
    "Ship Type (VESSEL TYPE)": "VESSEL TYPE",
    "Cause of Loss": "CAUSE OF LOSS"
}


m_WWI = folium.Map(
    location=[df_periode["LATITUDE"].mean(), df_periode["LONGITUDE"].mean()],
    zoom_start=4
)

# On crée les couleurs qui seront utilisées dans la légende
def make_color_dict(values):
    unique_vals = sorted(values.unique())
    cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
    return {cat: colors.rgb2hex(cmap(i)) for i, cat in enumerate(unique_vals)}


legends = ""

# On crée les layers et les légendes
for layer_name, col in categories.items():

    layer = folium.FeatureGroup(name=layer_name, show=False)

    color_dict = make_color_dict(df_periode[col])

    # On ajoute les points selon les coordonnées
    for _, row in df_periode.iterrows():
        color = color_dict[row[col]]
        folium.CircleMarker(
            location=[row["LATITUDE"], row["LONGITUDE"]],
            radius=4,
            popup=f"<b>{row['SHIPS NAME']}</b><br>{col}: {row[col]}",
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=0.7
        ).add_to(layer)

    m_WWI.add_child(layer)

    # On crée la légende dans une boîte en bas à gauche de la carte (c'est en html)
    legend_html = f"""
    <div id="legend_{layer_name.replace(' ', '_')}"
         style="display:none;
                position: fixed;
                bottom: 30px;
                left: 30px;
                z-index:9999;
                background-color: white;
                border:2px solid grey;
                padding:10px;
                font-size:13px;">
    <b>{layer_name}</b><br>
    """

    for cat, col_hex in color_dict.items():
        legend_html += f"""
        <i style="background:{col_hex};
                  width:12px;height:12px;
                  float:left;margin-right:6px;"></i>{cat}<br>
        """

    legend_html += "</div>"
    legends += legend_html

# Ajouter les légendes à la carte
m_WWI.get_root().html.add_child(folium.Element(legends))

# Script pour que ce soit la bonne légende qui s'affiche en fonction du layer
# le script est en java (ça marche car folium se base sur leaflet qui est une bibliothèque de java)
js = """
<script>

function hideLegends() {
    document.querySelectorAll('[id^=legend_]').forEach(el => {
        el.style.display = "none";
    });
}

// Exécuter au chargement
hideLegends();

// Intercepter les clics dans le LayerControl
document.addEventListener("change", function(e) {
    if (e.target.classList.contains("leaflet-control-layers-selector")) {

        hideLegends();

        if (e.target.checked) {
            // retrouver le nom du layer dans le label voisin
            let label = e.target.nextSibling.innerText.trim();
            let id = "legend_" + label.replaceAll(" ", "_");
            let legendEl = document.getElementById(id);
            if (legendEl) { legendEl.style.display = "block"; }
        }
    }
});

</script>
"""

m_WWI.get_root().html.add_child(folium.Element(js))

# Ajouter LayerControl
folium.LayerControl().add_to(m_WWI)

m_WWI
# Out:
# /tmp/ipython-input-3498939161.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# /tmp/ipython-input-3498939161.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# /tmp/ipython-input-3498939161.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9d0a80e07d8c2aeedd811dc55f9a9cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&quot;legend_Materials_(CONSTRUCTION)&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Materials (CONSTRUCTION)&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Steel&lt;br&gt;
#
#         &lt;i style=&quot;background:#8c564b;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Unknown&lt;br&gt;
#
#         &lt;i style=&quot;background:#9edae5;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Wood&lt;br&gt;
#         &lt;/div&gt;
#     &lt;div id=&quot;legend_Ship_Type_(VESSEL_TYPE)&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Ship Type (VESSEL TYPE)&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Freighter&lt;br&gt;
#
#         &lt;i style=&quot;background:#ff7f0e;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Other&lt;br&gt;
#
#         &lt;i style=&quot;background:#98df8a;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Passenger cargo ship&lt;br&gt;
#
#         &lt;i style=&quot;background:#9467bd;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Sailing ship&lt;br&gt;
#
#         &lt;i style=&quot;background:#c49c94;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Schooner&lt;br&gt;
#
#         &lt;i style=&quot;background:#7f7f7f;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Schooner - Barge&lt;br&gt;
#
#         &lt;i style=&quot;background:#dbdb8d;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Schooner 3 masted&lt;br&gt;
#
#         &lt;i style=&quot;background:#9edae5;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Steamship&lt;br&gt;
#         &lt;/div&gt;
#     &lt;div id=&quot;legend_Cause_of_Loss&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Cause of Loss&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Foundered&lt;br&gt;
#
#         &lt;i style=&quot;background:#2ca02c;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Foundered in storm&lt;br&gt;
#
#         &lt;i style=&quot;background:#9467bd;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Grounded&lt;br&gt;
#
#         &lt;i style=&quot;background:#e377c2;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Other&lt;br&gt;
#
#         &lt;i style=&quot;background:#bcbd22;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Stranded&lt;br&gt;
#
#         &lt;i style=&quot;background:#9edae5;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Unknown&lt;br&gt;
#         &lt;/div&gt;
#
# &lt;script&gt;
#
# function hideLegends() {
#     document.querySelectorAll(&#x27;[id^=legend_]&#x27;).forEach(el =&gt; {
#         el.style.display = &quot;none&quot;;
#     });
# }
#
# // Exécuter au chargement
# hideLegends();
#
# // Intercepter les clics dans le LayerControl
# document.addEventListener(&quot;change&quot;, function(e) {
#     if (e.target.classList.contains(&quot;leaflet-control-layers-selector&quot;)) {
#
#         hideLegends();
#
#         if (e.target.checked) {
#             // retrouver le nom du layer dans le label voisin
#             let label = e.target.nextSibling.innerText.trim();
#             let id = &quot;legend_&quot; + label.replaceAll(&quot; &quot;, &quot;_&quot;);
#             let legendEl = document.getElementById(id);
#             if (legendEl)

# %%
m_WWI.save("carte_WWI.html")

# %% [markdown]
# ## WWII

# %%
# On sélectionne les dates
periode = "WWII (1939–1945)"
df_periode = df[df["PERIODE"] == periode].copy()

# On définit les catégories qu'on voudra afficher dans les différents layers
categories = {
    "Materials (CONSTRUCTION)": "CONSTRUCTION",
    "Ship Type (VESSEL TYPE)": "VESSEL TYPE",
    "Cause of Loss": "CAUSE OF LOSS"
}


m_WWII = folium.Map(
    location=[df_periode["LATITUDE"].mean(), df_periode["LONGITUDE"].mean()],
    zoom_start=4
)

# On crée les couleurs qui seront utilisées dans la légende
def make_color_dict(values):
    unique_vals = sorted(values.unique())
    cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
    return {cat: colors.rgb2hex(cmap(i)) for i, cat in enumerate(unique_vals)}


legends = ""

# On crée les layers et les légendes
for layer_name, col in categories.items():

    layer = folium.FeatureGroup(name=layer_name, show=False)

    color_dict = make_color_dict(df_periode[col])

    # On ajoute les points selon les coordonnées
    for _, row in df_periode.iterrows():
        color = color_dict[row[col]]
        folium.CircleMarker(
            location=[row["LATITUDE"], row["LONGITUDE"]],
            radius=4,
            popup=f"<b>{row['SHIPS NAME']}</b><br>{col}: {row[col]}",
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=0.7
        ).add_to(layer)

    m_WWII.add_child(layer)

    # On crée la légende dans une boîte en bas à gauche de la carte (c'est en html)
    legend_html = f"""
    <div id="legend_{layer_name.replace(' ', '_')}"
         style="display:none;
                position: fixed;
                bottom: 30px;
                left: 30px;
                z-index:9999;
                background-color: white;
                border:2px solid grey;
                padding:10px;
                font-size:13px;">
    <b>{layer_name}</b><br>
    """

    for cat, col_hex in color_dict.items():
        legend_html += f"""
        <i style="background:{col_hex};
                  width:12px;height:12px;
                  float:left;margin-right:6px;"></i>{cat}<br>
        """

    legend_html += "</div>"
    legends += legend_html

# Ajouter les légendes à la carte
m_WWII.get_root().html.add_child(folium.Element(legends))

# Script pour que ce soit la bonne légende qui s'affiche en fonction du layer
# le script est en java (ça marche car folium se base sur leaflet qui est une bibliothèque de java)
js = """
<script>

function hideLegends() {
    document.querySelectorAll('[id^=legend_]').forEach(el => {
        el.style.display = "none";
    });
}

// Exécuter au chargement
hideLegends();

// Intercepter les clics dans le LayerControl
document.addEventListener("change", function(e) {
    if (e.target.classList.contains("leaflet-control-layers-selector")) {

        hideLegends();

        if (e.target.checked) {
            // retrouver le nom du layer dans le label voisin
            let label = e.target.nextSibling.innerText.trim();
            let id = "legend_" + label.replaceAll(" ", "_");
            let legendEl = document.getElementById(id);
            if (legendEl) { legendEl.style.display = "block"; }
        }
    }
});

</script>
"""

m_WWII.get_root().html.add_child(folium.Element(js))

# Ajouter LayerControl
folium.LayerControl().add_to(m_WWII)

m_WWII
# Out:
# /tmp/ipython-input-3056923727.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# /tmp/ipython-input-3056923727.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# /tmp/ipython-input-3056923727.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(unique_vals)) # On prend la cmap (map de couleur) nommé tab20
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_828ee03d4bd3b61e38f53e9381d27b1e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&quot;legend_Materials_(CONSTRUCTION)&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Materials (CONSTRUCTION)&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Steel&lt;br&gt;
#
#         &lt;i style=&quot;background:#9edae5;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Unknown&lt;br&gt;
#         &lt;/div&gt;
#     &lt;div id=&quot;legend_Ship_Type_(VESSEL_TYPE)&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Ship Type (VESSEL TYPE)&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Barge&lt;br&gt;
#
#         &lt;i style=&quot;background:#ff7f0e;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Freighter&lt;br&gt;
#
#         &lt;i style=&quot;background:#98df8a;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Freighter steam&lt;br&gt;
#
#         &lt;i style=&quot;background:#ff9896;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Motor vessel&lt;br&gt;
#
#         &lt;i style=&quot;background:#8c564b;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Motor vessel diesel&lt;br&gt;
#
#         &lt;i style=&quot;background:#e377c2;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Other&lt;br&gt;
#
#         &lt;i style=&quot;background:#c7c7c7;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Schooner - Barge&lt;br&gt;
#
#         &lt;i style=&quot;background:#dbdb8d;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Steamer cargo &lt;br&gt;
#
#         &lt;i style=&quot;background:#9edae5;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Tanker&lt;br&gt;
#         &lt;/div&gt;
#     &lt;div id=&quot;legend_Cause_of_Loss&quot;
#          style=&quot;display:none;
#                 position: fixed;
#                 bottom: 30px;
#                 left: 30px;
#                 z-index:9999;
#                 background-color: white;
#                 border:2px solid grey;
#                 padding:10px;
#                 font-size:13px;&quot;&gt;
#     &lt;b&gt;Cause of Loss&lt;/b&gt;&lt;br&gt;
#
#         &lt;i style=&quot;background:#1f77b4;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Burned&lt;br&gt;
#
#         &lt;i style=&quot;background:#d62728;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Foundered&lt;br&gt;
#
#         &lt;i style=&quot;background:#f7b6d2;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Other&lt;br&gt;
#
#         &lt;i style=&quot;background:#9edae5;
#                   width:12px;height:12px;
#                   float:left;margin-right:6px;&quot;&gt;&lt;/i&gt;Unknown&lt;br&gt;
#         &lt;/div&gt;
#
# &lt;script&gt;
#
# function hideLegends() {
#     document.querySelectorAll(&#x27;[id^=legend_]&#x27;).forEach(el =&gt; {
#         el.style.display = &quot;none&quot;;
#     });
# }
#
# // Exécuter au chargement
# hideLegends();
#
# // Intercepter les clics dans le LayerControl
# document.addEventListener(&quot;change&quot;, function(e) {
#     if (e.target.classList.contains(&quot;leaflet-control-layers-selector&quot;)) {
#
#         hideLegends();
#
#         if (e.target.checked) {
#             // retrouver le nom du layer dans le label voisin
#             let label = e.target.nextSibling.innerText.trim();
#             let id = &quot;legend_&quot; + label.replaceAll(&quot; &quot;, &quot;_&quot;);
#             let legendEl = document.getElementById(id);
#             if (legendEl) { legendEl.style.display = &quot;block&quot;; }
#         }
#     }
# });
#
# &lt;/script&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_828ee03d4bd3b61e38f53e9381d27b1e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_828ee03d4bd3b61e38f53e9381d27b1e = L.map(
#                 &quot;map_828ee03d4bd3b61e38f53e9381d27b

# %%
m_WWII.save("carte_WWII.html")

# %% [markdown]
# # Analyse

# %% [markdown]
# En observant les cartes, on peut observer que le nombre de naufrages diminue au fil des années (seulement 5 entre 1975 et 2025 contre 18 entre 1950 et 1975).
#
# On peut également observer que le nombre de naufrage de navire en bois diminue, cela est très probablement dû que les navires en bois ne sont plus produit (du moins beaucoup moins qu'avant) tandis que les navires en acier sont toujours produits. Il y a donc une augementation de la solidité des matériaux.
#
# Les types de navires les plus représentés entre avant 199 et 1950 sont les schooner (goélette). Entre 1975 et 2000 c'est les bâteaux à moteur et à partir de 1975 les tanker (bateau citerne) se font plus présent. On observe donc une évolution dans la taille des navires, ils deviennent de plus en plus grand. A côté de ça on observe qu'il n'y a pas de navires de guerre lors des guerres mondiales car les données ne sont pas sur le lieu des conflits.
#
# La cause des naufrages évolue également avec le temps, au début il y a des causes diverses comme échouage, incendie, le navire qui coule, tempête etc. Mais avec le temps on observe que la cause de naufrage qui persiste est foundered (le navire coule). Cela peut être dû à de l'eau qui s'infiltre dans le navire via des tuyaux corrodés (les tuyaux en question servent à refroidir les moteurs), un tangage trop important, une voie d'eau, fausse maneuvre etc. Les causes sont donc des erreurs humaines car il peut y avoir des erreurs lors des maneuvres et navigations ou manque de maintenance.
#
# Ce qu'on peut conclure c'est qu'il y a moins de naufrages car les navires sont plus grands, plus résistants et plus performants. En parallèle les systèmes de navigations et météos sont plus développée ce qui évite des risques inutiles (tempêtes, se perdre etc). Et quand il y a un naufrage c'est souvent d'origine humaine.
