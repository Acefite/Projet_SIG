# %% [markdown]
# <a href="https://colab.research.google.com/github/Acefite/Projet_SIG/blob/main/MachineLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Projet de Machine Learning**
# **Etude de la classification orthopédique de différentes configuration de colonnes vertébrales**
#
# CHAMPION Charles ; ZUCCHIATTI Virgile

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Les douleurs de dos sont parmi les problèmes de santé les plus courants et peuvent être liées à des pathologies comme l’hernie discale ou le spondylolisthésis. Les mesures radiologiques du bassin et de la colonne, telles que l’incidence pelvienne, la lordose lombaire ou le pelvic tilt, décrivent la posture et l’équilibre de la base de la colonne vertébrale. En analysant ces paramètres, il devient possible d’identifier des schémas caractéristiques et de prédire la nature des troubles du dos. Ainsi, l’étude des données biomécaniques offre un outil précieux pour améliorer le diagnostic et la compréhension des maux de dos.

# %% [markdown]
# Afin de pouvoir en apprendre plus sur les différents types de configurations de vertèbres causant des problèmes de dos, nous avons utilisé un dataset disponible sur Kaggle au lien suivant : [Lien](https://www.kaggle.com/datasets/caesarlupum/vertebralcolumndataset/data?select=column_2C.csv)

# %% [markdown]
# La problématique qui se pose alors est la suivante :
# # Quelles configurations de la colonne vertébrale sont susceptibles de favoriser l'apparition de pathologies ?

# %%
# Import des librairies
import pandas as pd
import matplotlib
import numpy as np
import kagglehub
import pandas as pd
import os
import matplotlib.pyplot as plt
#scikit learn
from scipy.stats import chi2_contingency
from sklearn.feature_selection import mutual_info_classif
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import seaborn as sns

# %% [markdown]
# # Import des datasets

# %% [markdown]
# Les données sont téléchargées sur le site Kaggle, sur la page il y a deux tables différents, on a donc deux cellules permettant de télécharger les tables (une cellule par .csv)

# %% [markdown]
# Premier .CSV

# %%
# Télécharger le dataset
path = kagglehub.dataset_download("caesarlupum/vertebralcolumndataset")
print("Path to dataset files:", path)

# Nom exact du fichier que l'on veux
csv_file = "column_2C.csv"

# Construire le chemin complet
full_csv_path = os.path.join(path, csv_file)

# Vérifier que le fichier existe
if os.path.exists(full_csv_path):
    df1 = pd.read_csv(full_csv_path)
    print("DataFrame loaded successfully.")
    print(df1.head())
else:
    print(f"Le fichier {csv_file} n'existe pas dans le répertoire: {path}")
# Out:
# Using Colab cache for faster access to the 'vertebralcolumndataset' dataset.
# Path to dataset files: /kaggle/input/vertebralcolumndataset
# DataFrame loaded successfully.
#    pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027817    22.552586              39.609117     40.475232
# 1         39.056951    10.060991              25.015378     28.995960
# 2         68.832021    22.218482              50.092194     46.613539
# 3         69.297008    24.652878              44.311238     44.644130
# 4         49.712859     9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis     class
# 0      98.672917                 -0.254400  Abnormal
# 1     114.405425                  4.564259  Abnormal
# 2     105.985135                 -3.530317  Abnormal
# 3     101.868495                 11.211523  Abnormal
# 4     108.168725                  7.918501  Abnormal

# %% [markdown]
# Second .CSV

# %%
# Télécharger le dataset
path = kagglehub.dataset_download("caesarlupum/vertebralcolumndataset")
print("Path to dataset files:", path)

# Nom exact du fichier que l'on veux
csv_file = "column_3C.csv"

# Construire le chemin complet
full_csv_path = os.path.join(path, csv_file)

# Vérifier que le fichier existe
if os.path.exists(full_csv_path):
    df2 = pd.read_csv(full_csv_path)
    print("DataFrame loaded successfully.")
    print(df2.head())
else:
    print(f"Le fichier {csv_file} n'existe pas dans le répertoire: {path}")
# Out:
# Using Colab cache for faster access to the 'vertebralcolumndataset' dataset.
# Path to dataset files: /kaggle/input/vertebralcolumndataset
# DataFrame loaded successfully.
#    pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027817    22.552586              39.609117     40.475232
# 1         39.056951    10.060991              25.015378     28.995960
# 2         68.832021    22.218482              50.092194     46.613539
# 3         69.297008    24.652878              44.311238     44.644130
# 4         49.712859     9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis   class
# 0      98.672917                 -0.254400  Hernia
# 1     114.405425                  4.564259  Hernia
# 2     105.985135                 -3.530317  Hernia
# 3     101.868495                 11.211523  Hernia
# 4     108.168725                  7.918501  Hernia

# %% [markdown]
# Pour la suite de l'étude on utilise la seconde table car elle comporte plus de précisions sur la nature des pathologies. (La différence entre les 2 ficheirs réside dans la colonne "class")

# %% [markdown]
# # Etude

# %% [markdown]
# **La signifiaction des mesures présentes dans les colonnes de la table sont :**
#
# *pelvic_incidence*  =>  Orientation anatomique du bassin (fixe)
#
# *pelvic_tilt*  =>  Bascule du bassin (réglable)
#
# *sacral_slope*  =>  Inclinaison du sacrum
#
# *lumbar_lordosis_angle*  =>  Courbure lombaire
#
# *pelvic_radius*  =>  Distance sacrum–hanches
#
# *degree_spondylolisthesis*  =>  Mesure du glissement vertébral

# %% [markdown]
# ![Human-vertebral-column.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![article_river_262833406e5f11eca4fa2ba1f065a7ff-Pelvic-Parameters1.png](data:image/png;base64,...)

# %% [markdown]
# ## Présentation générale du dataset

# %%
df2
# Out:
#      pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0           63.027817    22.552586              39.609117     40.475232
# 1           39.056951    10.060991              25.015378     28.995960
# 2           68.832021    22.218482              50.092194     46.613539
# 3           69.297008    24.652878              44.311238     44.644130
# 4           49.712859     9.652075              28.317406     40.060784
# ..                ...          ...                    ...           ...
# 305         47.903565    13.616688              36.000000     34.286877
# 306         53.936748    20.721496              29.220534     33.215251
# 307         61.446597    22.694968              46.170347     38.751628
# 308         45.252792     8.693157              41.583126     36.559635
# 309         33.841641     5.073991              36.641233     28.767649
#
#      pelvic_radius  degree_spondylolisthesis   class
# 0        98.672917                 -0.254400  Hernia
# 1       114.405425                  4.564259  Hernia
# 2       105.985135                 -3.530317  Hernia
# 3       101.868495                 11.211523  Hernia
# 4       108.168725                  7.918501  Hernia
# ..             ...                       ...     ...
# 305     117.449062                 -4.245395  Normal
# 306     114.365845                 -0.421010  Normal
# 307     125.670725                 -2.707880  Normal
# 308     118.545842                  0.214750  Normal
# 309     123.945244                 -0.199249  Normal
#
# [310 rows x 7 columns]

# %% [markdown]
# On peut observer que le dataset est composé de 7 colonnes et 310 lignes.

# %% [markdown]
# On affiche ensuite les 5 premières lignes du dataset.

# %%
df2.head()
# Out:
#    pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027817    22.552586              39.609117     40.475232
# 1         39.056951    10.060991              25.015378     28.995960
# 2         68.832021    22.218482              50.092194     46.613539
# 3         69.297008    24.652878              44.311238     44.644130
# 4         49.712859     9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis   class
# 0      98.672917                 -0.254400  Hernia
# 1     114.405425                  4.564259  Hernia
# 2     105.985135                 -3.530317  Hernia
# 3     101.868495                 11.211523  Hernia
# 4     108.168725                  7.918501  Hernia

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pelvic_incidence          310 non-null    float64
#  1   pelvic_tilt               310 non-null    float64
#  2   lumbar_lordosis_angle     310 non-null    float64
#  3   sacral_slope              310 non-null    float64
#  4   pelvic_radius             310 non-null    float64
#  5   degree_spondylolisthesis  310 non-null    float64
#  6   class                     310 non-null    object
# dtypes: float64(6), object(1)
# memory usage: 17.1+ KB

# %%
df2.describe()
# Out:
#        pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# count        310.000000   310.000000             310.000000    310.000000
# mean          60.496653    17.542822              51.930930     42.953831
# std           17.236520    10.008330              18.554064     13.423102
# min           26.147921    -6.554948              14.000000     13.366931
# 25%           46.430294    10.667069              37.000000     33.347122
# 50%           58.691038    16.357689              49.562398     42.404912
# 75%           72.877696    22.120395              63.000000     52.695889
# max          129.834041    49.431864             125.742385    121.429566
#
#        pelvic_radius  degree_spondylolisthesis
# count     310.000000                310.000000
# mean      117.920655                 26.296694
# std        13.317377                 37.559027
# min        70.082575                -11.058179
# 25%       110.709196                  1.603727
# 50%       118.268178                 11.767933
# 75%       125.467675                 41.287352
# max       163.071041                418.543082

# %% [markdown]
# Avec le .describe() du dataset, on observe plusieurs tendances qui peuvent se traduire en tendances physiologiques.
#
# La variable pelvic_incidence montre qu'il y a une grande diversité anatomique du bassin dans la population étudiée.
#
# La variable pelvic_tilt montre qu'il peut y avoir une forte diversité de posture (la bascule du bassin est influencé par la façon dont se tiennent les gens).
#
# La variable lumbar_lordosis_angle montre que certains patients ont une colonne “plate”, d’autres une hyperlordose (courbure excessive de la colonne).
#
# La variable sacral_slope présente une grande variation, ce qui prouve la présence de différents profils posturaux.
#
# La variable pelvic_radius est assez stable, ce qui reflète une caractéristique morphologique moins influencée par la pathologie.
#
# La variable degree_spondylolisthesis est très variable, ce qui peut se traduire par le fait que de nombreux patients du dataset souffre de pathologies.

# %%
df2['class'].value_counts()
# On compte le nombre de patients souffrants par pathologie
# Out:
# class
# Spondylolisthesis    150
# Normal               100
# Hernia                60
# Name: count, dtype: int64

# %% [markdown]
# Les variables présentes dans le dataset sont de types numériques (pour les mesures).
#
# La dernière colonne présente une variable catégorielle qui sera la variable cible lors de l'implémentation du machine learning, on cherchera à savoir la nature de la pathologie des patients.

# %% [markdown]
# ## Qualité du dataset

# %% [markdown]
# On vérifie si il y a des cellules qui sont vides (valeurs manquantes).

# %%
df2.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# On observe qu'il ne manque pas de valeurs (la valeur retournée est égale à 0).

# %% [markdown]
# On vérifie si il y a des doublons (deux lignes stictement identiques).

# %%
#Affiche les doublons :

df2[df2.duplicated()]
# Out:
# Empty DataFrame
# Columns: [pelvic_incidence, pelvic_tilt, lumbar_lordosis_angle, sacral_slope, pelvic_radius, degree_spondylolisthesis, class]
# Index: []

# %% [markdown]
# On observe qu'il n'y a pas de doublon.

# %% [markdown]
# Pour chaque colonnes, on vérifie le nombre de valeurs uniques. On fait ça pour vérifier le nombre de répétitions.

# %%
df2.nunique()
# Out:
# pelvic_incidence            310
# pelvic_tilt                 310
# lumbar_lordosis_angle       280
# sacral_slope                279
# pelvic_radius               310
# degree_spondylolisthesis    310
# class                         3
# dtype: int64

# %% [markdown]
# On observe qu'il y a des répétitions pour les colonnes lumbar_lordosis_angle et sacral_slope.

# %% [markdown]
# ## Etude des valeurs abberantes

# %% [markdown]
# On regarde si il y a des valeurs abberantes.

# %%
# Sélectionner uniquement les colonnes numériques
df_num = df2.select_dtypes(include='number')

Q1 = df_num.quantile(0.25)
Q3 = df_num.quantile(0.75)
IQR = Q3 - Q1

outliers = (df_num < (Q1 - 1.5 * IQR)) | (df_num > (Q3 + 1.5 * IQR))
df_num[outliers].dropna(how="all")
# Out:
#      pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 9                 NaN          NaN                    NaN           NaN
# 51                NaN    41.557331                    NaN           NaN
# 65                NaN    41.286305                    NaN           NaN
# 71                NaN          NaN                    NaN           NaN
# 75                NaN    39.822724                    NaN           NaN
# 76                NaN          NaN                    NaN           NaN
# 83                NaN          NaN                    NaN           NaN
# 84                NaN    42.396204                    NaN           NaN
# 85                NaN          NaN                    NaN           NaN
# 95                NaN          NaN                    NaN           NaN
# 112               NaN    -6.554948                    NaN           NaN
# 115        129.834041          NaN                    NaN    121.429566
# 122               NaN    48.069531                    NaN           NaN
# 136               NaN    39.844669                    NaN           NaN
# 141               NaN    48.903653                    NaN           NaN
# 143               NaN          NaN                    NaN           NaN
# 145               NaN    42.689195                    NaN           NaN
# 155               NaN          NaN                    NaN           NaN
# 162        118.144655          NaN                    NaN           NaN
# 163        115.923261          NaN                    NaN           NaN
# 167               NaN          NaN                    NaN           NaN
# 173               NaN          NaN                    NaN           NaN
# 179               NaN    49.431864                    NaN           NaN
# 180               NaN          NaN                    NaN           NaN
# 190               NaN          NaN                    NaN           NaN
# 191               NaN    40.303766                    NaN           NaN
# 192               NaN          NaN                    NaN           NaN
# 197               NaN          NaN             125.742385           NaN
# 202               NaN    41.933683                    NaN           NaN
# 206               NaN    46.550053                    NaN           NaN
# 304               NaN          NaN                    NaN           NaN
#
#      pelvic_radius  degree_spondylolisthesis
# 9        84.241415                       NaN
# 51             NaN                       NaN
# 65             NaN                       NaN
# 71             NaN                101.719092
# 75      148.525562                145.378143
# 76             NaN                110.860782
# 83      151.839857                       NaN
# 84             NaN                       NaN
# 85      163.071041                       NaN
# 95             NaN                148.753711
# 112            NaN                       NaN
# 115            NaN                418.543082
# 122            NaN                       NaN
# 136            NaN                       NaN
# 141            NaN                118.353370
# 143            NaN                104.859247
# 145            NaN                       NaN
# 155      82.456038                       NaN
# 162      81.024541                       NaN
# 163            NaN                       NaN
# 167      70.082575                       NaN
# 173      78.999454                       NaN
# 179            NaN                       NaN
# 180     157.848799                       NaN
# 190      88.434242                       NaN
# 191            NaN                       NaN
# 192            NaN                124.984406
# 197            NaN                117.314683
# 202            NaN                101.218783
# 206            NaN                       NaN
# 304     147.894637                       NaN

# %% [markdown]
# On observe la présence de plusieurs valeurs abberantes dans le dataset.

# %% [markdown]
# Pour limiter l'impact des valeurs aberrantes lors de l'étude statistique du dataset, on va utiliser la Winsorisation qui fait exactement ça.

# %%
from scipy.stats.mstats import winsorize

# Sélection des colonnes numériques
df_num = df2.select_dtypes(include='number').copy()

# Winsorisation à 1% aux deux extrémités, le paramètre peut être modifié (limits)
df_winsorized = df_num.apply(lambda col: winsorize(col, limits=[0.04, 0.04]))

# %% [markdown]
# On regarde les nouvelles statistiques après winsorisation.

# %%
df_winsorized.describe()
# Out:
#        pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# count        310.000000   310.000000             310.000000    310.000000
# mean          60.203721    17.484874              51.855416     42.674264
# std           16.019781     9.280366              17.575930     11.822091
# min           34.756738     1.835524              25.323565     22.579573
# 25%           46.430294    10.667069              37.000000     33.347122
# 50%           58.691038    16.357689              49.562398     42.404912
# 75%           72.877696    22.120395              63.000000     52.695889
# max           89.504947    38.750670              89.600000     64.358994
#
#        pelvic_radius  degree_spondylolisthesis
# count     310.000000                310.000000
# mean      117.925974                 24.549112
# std        11.811582                 27.869591
# min        94.018783                 -4.497958
# 25%       110.709196                  1.603727
# 50%       118.268178                 11.767933
# 75%       125.467675                 41.287352
# max       139.414504                 92.027277

# %% [markdown]
# On transfère les données du dataframe Winsorizé dans le dataframe qu'on utilise.

# %%
df2[df_num.columns] = df_winsorized

# %% [markdown]
# On revérifie la présence de valeurs abberantes dans le dataset.

# %%
# Sélectionner uniquement les colonnes numériques
df_num = df2.select_dtypes(include='number')

Q1 = df_num.quantile(0.25)
Q3 = df_num.quantile(0.75)
IQR = Q3 - Q1

outliers = (df_num < (Q1 - 1.5 * IQR)) | (df_num > (Q3 + 1.5 * IQR))
df_num[outliers].dropna(how="all")
# Out:
# Empty DataFrame
# Columns: [pelvic_incidence, pelvic_tilt, lumbar_lordosis_angle, sacral_slope, pelvic_radius, degree_spondylolisthesis]
# Index: []

# %% [markdown]
# On observe qu'il n'y a plus de valeurs abberantes après winsorisation.

# %% [markdown]
# # Etude statistique

# %% [markdown]
# On regarde la moyenne de chaque paramètres pour chacune des classes :

# %%
df2_means = df2.groupby("class").mean()

df2_means
# Out:
#                    pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  \
# class
# Hernia                    48.074390    17.352017              36.169226
# Normal                    51.762888    13.033228              43.659541
# Spondylolisthesis         70.682677    20.505780              63.593809
#
#                    sacral_slope  pelvic_radius  degree_spondylolisthesis
# class
# Hernia                30.877332     116.637924                  2.824610
# Normal                38.917349     123.746621                  2.377588
# Spondylolisthesis     49.897646     114.560762                 48.019928

# %% [markdown]
# Distribution des variables:

# %%
df2.hist(figsize=(12,8), bins=20)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

sns.histplot(df2['pelvic_radius'], kde=True)
# Out:
# <Axes: xlabel='pelvic_radius', ylabel='Count'>

# %% [markdown]
# ## Corrélation entre les variables :

# %%
corr = df2.corr(numeric_only=True)
corr
# Out:
#                           pelvic_incidence  pelvic_tilt  \
# pelvic_incidence                  1.000000     0.662501
# pelvic_tilt                       0.662501     1.000000
# lumbar_lordosis_angle             0.764119     0.452077
# sacral_slope                      0.795554     0.094333
# pelvic_radius                    -0.242660     0.034118
# degree_spondylolisthesis          0.684322     0.517244
#
#                           lumbar_lordosis_angle  sacral_slope  pelvic_radius  \
# pelvic_incidence                       0.764119      0.795554      -0.242660
# pelvic_tilt                            0.452077      0.094333       0.034118
# lumbar_lordosis_angle                  1.000000      0.659733      -0.094596
# sacral_slope                           0.659733      1.000000      -0.361749
# pelvic_radius                         -0.094596     -0.361749       1.000000
# degree_spondylolisthesis               0.693758      0.489301      -0.070703
#
#                           degree_spondylolisthesis
# pelvic_incidence                          0.684322
# pelvic_tilt                               0.517244
# lumbar_lordosis_angle                     0.693758
# sacral_slope                              0.489301
# pelvic_radius                            -0.070703
# degree_spondylolisthesis                  1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# ## Etude relations cible/features :

# %%
plt.figure(figsize=(12,8))
df2.boxplot(by='class', figsize=(12,10))
plt.show()

# %% [markdown]
# cas par cas, code à adapter :

# %%
sns.boxplot(data=df2, x='class', y='pelvic_incidence')
plt.show()

# %%
sns.boxplot(data=df2, x='class', y='pelvic_tilt')
plt.show()

# %%
sns.boxplot(data=df2, x='class', y='sacral_slope')
plt.show()

# %%
sns.boxplot(data=df2, x='class', y='pelvic_radius')
plt.show()

# %%
sns.boxplot(data=df2, x='class', y='degree_spondylolisthesis')
plt.show()

# %%
sns.boxplot(data=df2, x='class', y='lumbar_lordosis_angle')
plt.show()

# %% [markdown]
# ## Dépendances entre les variables catégorielles :

# %%
df2['high_lordosis'] = (df2['lumbar_lordosis_angle'] > df2['lumbar_lordosis_angle'].median()).astype(int)

# Table de contingence
ct = pd.crosstab(df2['high_lordosis'], df2['class'])
print(ct)

# Plot
ct.plot(kind='bar')
plt.xlabel('High lordosis (0 = inférieur à médiane, 1 = supérieur à médiane)')
plt.ylabel('Nombre d’individus')
plt.title('Répartition des classes selon lumbar_lordosis_angle')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# class          Hernia  Normal  Spondylolisthesis
# high_lordosis
# 0                  56      70                 29
# 1                   4      30                121

# %%
df2['high_pelvic_incidence'] = (df2['pelvic_incidence'] > df2['pelvic_incidence'].median()).astype(int)

# Table de contingence
ct = pd.crosstab(df2['high_pelvic_incidence'], df2['class'])
print(ct)

# Plot
ct.plot(kind='bar')
plt.xlabel('High pelvic_incidence (0 = inférieur à médiane, 1 = supérieur à médiane)')
plt.ylabel('Nombre d’individus')
plt.title('Répartition des classes selon pelvic_incidence')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# class                  Hernia  Normal  Spondylolisthesis
# high_pelvic_incidence
# 0                          51      72                 32
# 1                           9      28                118

# %%
df2['high_pelvic_tilt'] = (df2['pelvic_tilt'] > df2['pelvic_tilt'].median()).astype(int)

# Table de contingence
ct = pd.crosstab(df2['high_pelvic_tilt'], df2['class'])
print(ct)

# Plot
ct.plot(kind='bar')
plt.xlabel('High 	pelvic_tilt (0 = inférieur à médiane, 1 = supérieur à médiane)')
plt.ylabel('Nombre d’individus')
plt.title('Répartition des classes selon 	pelvic_tilt')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# class             Hernia  Normal  Spondylolisthesis
# high_pelvic_tilt
# 0                     28      69                 58
# 1                     32      31                 92
# /tmp/ipython-input-3335485731.py:13: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df2['high_sacral_slope'] = (df2['sacral_slope'] > df2['sacral_slope'].median()).astype(int)

# Table de contingence
ct = pd.crosstab(df2['high_sacral_slope'], df2['class'])
print(ct)

# Plot
ct.plot(kind='bar')
plt.xlabel('High sacral_slope (0 = inférieur à médiane, 1 = supérieur à médiane)')
plt.ylabel('Nombre d’individus')
plt.title('Répartition des classes selon sacral_slope')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# class              Hernia  Normal  Spondylolisthesis
# high_sacral_slope
# 0                      57      65                 33
# 1                       3      35                117

# %%
df2['high_pelvic_radius'] = (df2['pelvic_radius'] > df2['pelvic_radius'].median()).astype(int)

# Table de contingence
ct = pd.crosstab(df2['high_pelvic_radius'], df2['class'])
print(ct)

# Plot
ct.plot(kind='bar')
plt.xlabel('High pelvic_radius (0 = inférieur à médiane, 1 = supérieur à médiane)')
plt.ylabel('Nombre d’individus')
plt.title('Répartition des classes selon pelvic_radius')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# class               Hernia  Normal  Spondylolisthesis
# high_pelvic_radius
# 0                       36      26                 93
# 1                       24      74                 57

# %%
df2['high_degree_spondylolisthesis'] = (df2['degree_spondylolisthesis'] > df2['degree_spondylolisthesis'].median()).astype(int)

# Table de contingence
ct = pd.crosstab(df2['high_degree_spondylolisthesis'], df2['class'])
print(ct)

# Plot
ct.plot(kind='bar')
plt.xlabel('High degree_spondylolisthesis (0 = inférieur à médiane, 1 = supérieur à médiane)')
plt.ylabel('Nombre d’individus')
plt.title('Répartition des classes selon degree_spondylolisthesis')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# class                          Hernia  Normal  Spondylolisthesis
# high_degree_spondylolisthesis
# 0                                  58      94                  3
# 1                                   2       6                147

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# On normalise les données pour pouvoir les utiliser par la suite dans différents modèles :

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df2.drop('class', axis=1))

# %% [markdown]
# On vérifie l'asymétrie des données :

# %%
df2.drop('class', axis=1).skew()
# Out:
# pelvic_incidence                 0.204362
# pelvic_tilt                      0.591625
# lumbar_lordosis_angle            0.474626
# sacral_slope                     0.111067
# pelvic_radius                   -0.171185
# degree_spondylolisthesis         0.905540
# high_lordosis                    0.000000
# high_pelvic_incidence            0.000000
# high_pelvic_tilt                 0.000000
# high_sacral_slope                0.000000
# high_pelvic_radius               0.000000
# high_degree_spondylolisthesis    0.000000
# dtype: float64

# %% [markdown]
# La valeur de "degree_spondylolisthesis" est proche de 1, on applique donc une transformation logarithmique :

# %%
df2['degree_spondylolisthesis_log'] = np.log1p(df2['degree_spondylolisthesis'])
# Out:
# /usr/local/lib/python3.12/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# Binning : Découpage en classes pour faciliter les interprétations futures

# %%
variables_to_bin = [
    'pelvic_incidence',
    'pelvic_tilt',
    'lumbar_lordosis_angle',
    'sacral_slope',
    'pelvic_radius',
    'degree_spondylolisthesis'
]

for var in variables_to_bin:
    df2[var + '_bin'] = pd.qcut(df2[var], q=3, labels=['low', 'medium', 'high'])

# %%
#Affichage de la table avec les classes créées
bin_cols = [var + '_bin' for var in variables_to_bin]
cols_order = bin_cols + ['class']
df2[cols_order]
# Out:
#     pelvic_incidence_bin pelvic_tilt_bin lumbar_lordosis_angle_bin  \
# 0                 medium            high                       low
# 1                    low             low                       low
# 2                   high            high                    medium
# 3                   high            high                    medium
# 4                    low             low                       low
# ..                   ...             ...                       ...
# 305                  low          medium                       low
# 306               medium            high                       low
# 307               medium            high                    medium
# 308                  low             low                       low
# 309                  low             low                       low
#
#     sacral_slope_bin pelvic_radius_bin degree_spondylolisthesis_bin   class
# 0             medium               low                          low  Hernia
# 1                low            medium                       medium  Hernia
# 2             medium               low                          low  Hernia
# 3             medium               low                       medium  Hernia
# 4             medium               low                       medium  Hernia
# ..               ...               ...                          ...     ...
# 305              low            medium                          low  Normal
# 306              low            medium                          low  Normal
# 307           medium              high                          low  Normal
# 308           medium            medium                          low  Normal
# 309              low              high                          low  Normal
#
# [310 rows x 7 columns]

# %% [markdown]
# On pourra visualiser ça plus tard pour voir la répartition de valeurs hautes ou bases

# %% [markdown]
# On va calculer des ratios biomécaniques pertinents, pour faire le lien avec les classes de colonnes vertébrales :

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# On  commence par le rapport pelvic_tilt/sacral_slope utile pour détecter une compensation posturale :

# %%
df2['VP/PS'] = df2['pelvic_tilt'] / df2['sacral_slope']

# %%
df2[['VP/PS','class']]
# Out:
#         VP/PS   class
# 0    0.557195  Hernia
# 1    0.346979  Hernia
# 2    0.476653  Hernia
# 3    0.552209  Hernia
# 4    0.240936  Hernia
# ..        ...     ...
# 305  0.397140  Normal
# 306  0.623855  Normal
# 307  0.585652  Normal
# 308  0.237780  Normal
# 309  0.176378  Normal
#
# [310 rows x 2 columns]

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df2, x='class', y='VP/PS')

plt.title("Distribution de VP/PS par classe")
plt.xlabel("Classe")
plt.ylabel("VP/PS")
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# On  calcule ensuite le rapport lumbar_lordosis_angle/pelvic_incidence utile pour mesurer l'adaptation du rachis (colonne vertébrale) à la morphologie pelvienne :

# %%
df2['LL/IP'] = df2['lumbar_lordosis_angle'] / df2['pelvic_incidence']

# %%
df2[['LL/IP','class']]
# Out:
#         LL/IP   class
# 0    0.628439  Hernia
# 1    0.648375  Hernia
# 2    0.727746  Hernia
# 3    0.639439  Hernia
# 4    0.569619  Hernia
# ..        ...     ...
# 305  0.751510  Normal
# 306  0.541756  Normal
# 307  0.751390  Normal
# 308  0.918907  Normal
# 309  1.054220  Normal
#
# [310 rows x 2 columns]

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df2, x='class', y='LL/IP')

plt.title("Distribution de LL/IP par classe")
plt.xlabel("Classe")
plt.ylabel("LL/IP")
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# Il y a également l'indice (pelvic_tilt + lumbar_lordosis)/sacral_slope qui capture à quel point la lordose (courbure de la colonne vertébrale d'avant en arrière) et la rétroversion (inclinaison en arrière) compensent une pente sacrée réduite :

# %%
df2['VP+LL/PS'] = (df2['pelvic_tilt'] + df2['lumbar_lordosis_angle'])/ df2['sacral_slope']

# %%
df2[['VP+LL/PS','class']]
# Out:
#      VP+LL/PS   class
# 0    1.535796  Hernia
# 1    1.220327  Hernia
# 2    1.551281  Hernia
# 3    1.544752  Hernia
# 4    0.947797  Hernia
# ..        ...     ...
# 305  1.447104  Normal
# 306  1.503587  Normal
# 307  1.777095  Normal
# 308  1.375186  Normal
# 309  1.450074  Normal
#
# [310 rows x 2 columns]

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df2, x='class', y='VP+LL/PS')

plt.title("Distribution de VP+LL/PS par classe")
plt.xlabel("Classe")
plt.ylabel("VP+LL/PS")
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# Il y a également le rapport degree_spondylolisthesis / pelvic_incidence lié au spondylolisthésis permettant de normaliser la séverité du glissement par la morphologie pelvienne :

# %%
df2['DS/PI'] = df2['degree_spondylolisthesis'] / df2['pelvic_incidence']

# %%
df2[['DS/PI','class']]
# Out:
#         DS/PI   class
# 0   -0.004036  Hernia
# 1    0.116862  Hernia
# 2   -0.051289  Hernia
# 3    0.161789  Hernia
# 4    0.159285  Hernia
# ..        ...     ...
# 305 -0.088624  Normal
# 306 -0.007806  Normal
# 307 -0.044069  Normal
# 308  0.004746  Normal
# 309 -0.005733  Normal
#
# [310 rows x 2 columns]

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df2, x='class', y='DS/PI')

plt.title("Distribution de DS/PI par classe")
plt.xlabel("Classe")
plt.ylabel("DS/PI")
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# On calcule aussi le déficit de lordose, dont un écart important explique certaines pathologies lombaires :

# %%
df2['PI/LL'] = df2['pelvic_incidence'] - df2['lumbar_lordosis_angle']

# %%
df2[['PI/LL','class']]
# Out:
#          PI/LL   class
# 0    23.418700  Hernia
# 1    13.733386  Hernia
# 2    18.739827  Hernia
# 3    24.985770  Hernia
# 4    21.395453  Hernia
# ..         ...     ...
# 305  11.903565  Normal
# 306  24.716214  Normal
# 307  15.276250  Normal
# 308   3.669666  Normal
# 309  -1.884495  Normal
#
# [310 rows x 2 columns]

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df2, x='class', y='PI/LL')

plt.title("Distribution de  par classe")
plt.xlabel("Classe")
plt.ylabel("PI/LL")
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# Enfin il y a le rapport lordose compensé qui évalue la cohérence de l'orientation de la lordose avec le sacrum :

# %%
df2['LL/PS'] = df2['lumbar_lordosis_angle'] - df2['sacral_slope']

# %%
df2[['LL/PS','class']]
# Out:
#          LL/PS   class
# 0    -0.866115  Hernia
# 1    -3.672395  Hernia
# 2     3.478655  Hernia
# 3    -0.332892  Hernia
# 4   -11.743378  Hernia
# ..         ...     ...
# 305   1.713123  Normal
# 306  -3.994717  Normal
# 307   7.418719  Normal
# 308   5.023491  Normal
# 309   7.873584  Normal
#
# [310 rows x 2 columns]

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df2, x='class', y='LL/PS')

plt.title("Distribution de LL/PS par classe")
plt.xlabel("Classe")
plt.ylabel("LL/PS")
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# Les différents ratios permettent de mettre en relation deux des six paramètres mesurés pour obtenir une nouvelle information. Mais les mesures du pelvic_radius ne sont utilisées nulle part.
#
# On peut emmetre l'hypothèse que la raison est que cette mesure est assez peu variable d'un individu à l'autre et n'apporte pas de réelles informations utiles dans le cadre de l'étude.
#
# On peut valider (ou non) cette hypothèse avec un mutual information.

# %%
# On isole les variables pour les mettre en x.
features = ['pelvic_incidence', 'pelvic_tilt', 'lumbar_lordosis_angle',
            'sacral_slope', 'pelvic_radius', 'degree_spondylolisthesis']

X = df2[features]
y = df2['class']


# Mutual Information
mi = mutual_info_classif(X, y, random_state=0)

# Transformation en DataFrame
mi_df = pd.DataFrame({
    'Variable': features,
    'Mutual_Information': mi
}).sort_values(by='Mutual_Information', ascending=False)

mi_df
# Out:
#                    Variable  Mutual_Information
# 5  degree_spondylolisthesis            0.597513
# 2     lumbar_lordosis_angle            0.271920
# 3              sacral_slope            0.249666
# 0          pelvic_incidence            0.242789
# 4             pelvic_radius            0.101288
# 1               pelvic_tilt            0.076427

# %% [markdown]
# Grâce au mutual information, on observe que l'hypothèse est fausse. Le paramètre le moins important n'est pas le pelvic_radius (même si il reste peu important) mais le pelvic_tilt.
#
# Nous pouvons également observer que le paramètre le plus important est le degree_spondylolisthesis.

# %% [markdown]
# ## Encodage

# %% [markdown]
# On fait un premier encodage pour distinguer les perosnnes en bonnes santé des personnes souffrantes.
#
# 0 correspond aux personnes en bonne santé et 1 aux personnes souffrantes.

# %%
df2["sante_encodage"] = df2["class"].apply(lambda x: 0 if x.lower() == "normal" else 1)

# %% [markdown]
# On fait un autre type d'encodage qui précisera la nature des pathologie (ou si une personne est en bonne santé).
#
# 0 correspond aux personnes en bonne santé et 1 aux personnes souffrantes d'hernie et 2 aux personnes souffrantes de spondylolisthesis.

# %%
def encode_pathologie(x):
    x = x.lower()
    if x == "normal":
        return 0
    elif x == "hernia":
        return 1
    else:
        return 2

df2["pathologie_encodage"] = df2["class"].apply(encode_pathologie)

# %% [markdown]
# On affiche le dataframe avec les nouvelles données!;

# %%
df2.head()
# Out:
#    pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027817    22.552586              39.609117     40.475232
# 1         39.056951    10.060991              25.323565     28.995960
# 2         68.832021    22.218482              50.092194     46.613539
# 3         69.297008    24.652878              44.311238     44.644130
# 4         49.712859     9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis   class  high_lordosis  \
# 0      98.672917                 -0.254400  Hernia              0
# 1     114.405425                  4.564259  Hernia              0
# 2     105.985135                 -3.530317  Hernia              1
# 3     101.868495                 11.211523  Hernia              0
# 4     108.168725                  7.918501  Hernia              0
#
#    high_pelvic_incidence  high_pelvic_tilt  ...  pelvic_radius_bin  \
# 0                      1                 1  ...                low
# 1                      0                 0  ...             medium
# 2                      1                 1  ...                low
# 3                      1                 1  ...                low
# 4                      0                 0  ...                low
#
#    degree_spondylolisthesis_bin     VP/PS     LL/IP  VP+LL/PS     DS/PI  \
# 0                           low  0.557195  0.628439  1.535796 -0.004036
# 1                        medium  0.346979  0.648375  1.220327  0.116862
# 2                           low  0.476653  0.727746  1.551281 -0.051289
# 3                        medium  0.552209  0.639439  1.544752  0.161789
# 4                        medium  0.240936  0.569619  0.947797  0.159285
#
#        PI/LL      LL/PS sante_encodage pathologie_encodage
# 0  23.418700  -0.866115              1                   1
# 1  13.733386  -3.672395              1                   1
# 2  18.739827   3.478655              1                   1
# 3  24.985770  -0.332892              1                   1
# 4  21.395453 -11.743378              1                   1
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Graphique multivarié : PCA

# %% [markdown]
# Le graphique PCA est une méthode permettant de visualiser en deux dimensions des données en trois ou plus dimensions (dans notre cas six). Pour cela, cette méthode crée des axes x et y basés sur l'influence des différentes variables sur les deux axes respectifs.
#
# Ce graphique permet de visualiser la position des classes selon les variables et si ils forment des clusters.

# %%
# Sélection des features
# On enlève la colonne "class" et les colonnes d'encodage
features = ['pelvic_incidence', 'pelvic_tilt', 'lumbar_lordosis_angle',
            'sacral_slope', 'pelvic_radius', 'degree_spondylolisthesis']

X = df2[features]
y = df2['class']   # labels pour colorer le graphique

# Standardisation
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# PCA (2 composantes)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Conversion en dataframe
df_pca = pd.DataFrame({
    'PCA1': X_pca[:, 0],
    'PCA2': X_pca[:, 1],
    'class': y
})

df_pca
# Out:
#          PCA1      PCA2   class
# 0   -0.295844 -1.040094  Hernia
# 1   -2.435336 -0.350406  Hernia
# 2    0.242122 -0.818265  Hernia
# 3    0.403646 -0.785307  Hernia
# 4   -1.500938 -1.121770  Hernia
# ..        ...       ...     ...
# 305 -1.718750 -0.186848  Normal
# 306 -1.387126  0.052778  Normal
# 307 -0.589044  0.694806  Normal
# 308 -1.694945 -0.420115  Normal
# 309 -2.649950 -0.023190  Normal
#
# [310 rows x 3 columns]

# %% [markdown]
# On affiche le "loading", c'est à dire un tableau qui montre l'influence de chaque paramètres sur les axes x et y du graphique PCA.
#
# Plus le résultat est proche de 1, plus la variable à un impact important (plus c'est proche de -1, plus l'influence est importante mais opposée).

# %%
loadings = pd.DataFrame(
    pca.components_.T,
    columns=['PCA1', 'PCA2'],
    index=features
)

print("Loadings (importance des variables dans chaque axe) :")
loadings
# Out:
# Loadings (importance des variables dans chaque axe) :
#                               PCA1      PCA2
# pelvic_incidence          0.518236 -0.005316
# pelvic_tilt               0.338197  0.506582
# lumbar_lordosis_angle     0.472743  0.056098
# sacral_slope              0.421744 -0.420739
# pelvic_radius            -0.141227  0.725551
# degree_spondylolisthesis  0.442442  0.191713

# %% [markdown]
# Grâce au loading on peut observer que les deux paramètres les plus influents pour l'axe x sont pelvic_incidence et lumbar_lordosis_angle. Pour l'axe y c'est pelvic_radius et pelvic_tilt.

# %% [markdown]
# On affiche le graphique :

# %%
plt.figure(figsize=(10, 7))
sns.scatterplot(data=df_pca, x='PCA1', y='PCA2', hue='class', palette='Set2', s=80, edgecolor='black')

plt.title("PCA - Visualisation des 2 premières composantes", fontsize=16)
plt.xlabel("PCA1 (%.2f%% de variance)" % (pca.explained_variance_ratio_[0] * 100))
plt.ylabel("PCA2 (%.2f%% de variance)" % (pca.explained_variance_ratio_[1] * 100))
plt.grid(True)
plt.show()

print("Variance expliquée par PCA1 et PCA2 :")
print(pca.explained_variance_ratio_)
# Out:
# Variance expliquée par PCA1 et PCA2 :
# [0.57119628 0.20156291]

# %% [markdown]
# Visuellement on peut observer que la classe Spondylolisthesis forme un pseudo cluster. Il est majoritairement présent dans la partie droite du graphique, avec une tendance vers le haut.
#
# Les classes normales et hernies sont plus présent à gauche du graphique mais il n'y a pas de différences notable entre les deux.

# %% [markdown]
# # Entrainement par Regression Logistique Multiclasses

# %% [markdown]
# Dans notre projet, nous avons utilisé un modèle de régression logistique multiclasses pour prédire la classe de pathologie rachidienne (Normal, Hernia, Spondylolisthesis) à partir de mesures biomécaniques du bassin et de la colonne vertébrale.

# %% [markdown]
# Notre variable cible (class) prends 3 valeurs discrètes distinctes. La régression logistique est particulièrement adaptée pour prédire le probabilité pour un patient d'avoir une pathologie. On réalise donc une un modèle multiclasse pour prendre en compte l'ensemble des paramètres.

# %%
#Import des librairies
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# On définit les mesures en paramètres et la pathologie en cible
features = ['pelvic_incidence', 'pelvic_tilt', 'lumbar_lordosis_angle', 'sacral_slope', 'pelvic_radius', 'degree_spondylolisthesis']
X = df2[features]

y = df2["class"]

# %%
print("Shape: ", X.shape, "Dimension: ", X.ndim)
print("Shape: ", y.shape, "Dimension: ", y.ndim)
# Out:
# Shape:  (310, 6) Dimension:  2
# Shape:  (310,) Dimension:  1

# %% [markdown]
# On prend 20% des entrées de la table en dataset de test, soit 62 entrées

# %%
# On sépare les données en données d'entraînement et en données de test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=23)

# %%
log_model = LogisticRegression()

# %% [markdown]
# # Essayer de MinMax scaled

# %%
# Fit the model
# Increased max_iter for convergence
log_model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions = log_model.predict(X_test)

# %%
y_test.values
# Out:
# array(['Spondylolisthesis', 'Normal', 'Spondylolisthesis', 'Hernia',
#        'Hernia', 'Hernia', 'Spondylolisthesis', 'Hernia', 'Normal',
#        'Normal', 'Spondylolisthesis', 'Normal', 'Spondylolisthesis',
#        'Spondylolisthesis', 'Normal', 'Normal', 'Spondylolisthesis',
#        'Hernia', 'Spondylolisthesis', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Spondylolisthesis', 'Normal', 'Hernia',
#        'Spondylolisthesis', 'Hernia', 'Spondylolisthesis',
#        'Spondylolisthesis', 'Spondylolisthesis', 'Spondylolisthesis',
#        'Spondylolisthesis', 'Normal', 'Spondylolisthesis', 'Normal',
#        'Spondylolisthesis', 'Normal', 'Spondylolisthesis', 'Normal',
#        'Normal', 'Spondylolisthesis', 'Normal', 'Spondylolisthesis',
#        'Spondylolisthesis', 'Normal', 'Hernia', 'Spondylolisthesis',
#        'Spondylolisthesis', 'Spondylolisthesis', 'Spondylolisthesis',
#        'Normal', 'Spondylolisthesis', 'Spondylolisthesis', 'Hernia',
#        'Normal', 'Spondylolisthesis', 'Spondylolisthesis',
#        'Spondylolisthesis', 'Normal', 'Normal', 'Normal'], dtype=object)

# %%
predictions
# Out:
# array(['Spondylolisthesis', 'Normal', 'Spondylolisthesis', 'Normal',
#        'Hernia', 'Hernia', 'Spondylolisthesis', 'Hernia', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Spondylolisthesis',
#        'Spondylolisthesis', 'Normal', 'Normal', 'Spondylolisthesis',
#        'Normal', 'Spondylolisthesis', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Spondylolisthesis', 'Normal', 'Hernia',
#        'Spondylolisthesis', 'Hernia', 'Spondylolisthesis',
#        'Spondylolisthesis', 'Spondylolisthesis', 'Spondylolisthesis',
#        'Spondylolisthesis', 'Normal', 'Spondylolisthesis', 'Hernia',
#        'Spondylolisthesis', 'Normal', 'Spondylolisthesis',
#        'Spondylolisthesis', 'Normal', 'Spondylolisthesis', 'Normal',
#        'Spondylolisthesis', 'Spondylolisthesis', 'Normal', 'Normal',
#        'Spondylolisthesis', 'Spondylolisthesis', 'Spondylolisthesis',
#        'Spondylolisthesis', 'Hernia', 'Spondylolisthesis',
#        'Spondylolisthesis', 'Hernia', 'Normal', 'Spondylolisthesis',
#        'Spondylolisthesis', 'Spondylolisthesis', 'Normal', 'Normal',
#        'Normal'], dtype=object)

# %%
confusion_matrix(y_test, predictions)
# Out:
# array([[ 6,  3,  0],
#        [ 2, 20,  1],
#        [ 0,  1, 29]])

# %%
#Matrice de confusion
ConfusionMatrixDisplay.from_predictions(y_test, predictions,
                                        display_labels=log_model.classes_,
                                        cmap='Blues',
                                        colorbar=True)

# %%
#Matrice de confusion normalisée
ConfusionMatrixDisplay.from_predictions(y_test, predictions, cmap='Blues', normalize='true')

# %% [markdown]
# La matrice de confusion est équilibrée : la quantité de faux positif est plutôt faible, et le modèle classifie bien les pathologies en faisant correctement la distinction entre colonne normale et spondylolisthesis. Il y a plus d'erreurs pour les hernies, qui proviennent notamment du fait que les valeurs de paramètres de Hernie sont très similaires aux colonnes normales.

# %%
accuracy_score(y_test, predictions)
# Out:
# 0.8870967741935484

# %% [markdown]
# ## Evaluation du modèle

# %%
from sklearn.metrics import classification_report
#Evaluation des métriques
print(classification_report(y_test, predictions))
# Out:
#                    precision    recall  f1-score   support
#
#            Hernia       0.75      0.67      0.71         9
#            Normal       0.83      0.87      0.85        23
# Spondylolisthesis       0.97      0.97      0.97        30
#
#          accuracy                           0.89        62
#         macro avg       0.85      0.83      0.84        62
#      weighted avg       0.89      0.89      0.89        62

# %%
#Courbe ROC-AUC pour chaque classe

from sklearn.metrics import RocCurveDisplay
from sklearn.preprocessing import label_binarize
from itertools import cycle
import matplotlib.pyplot as plt

# Binarize the target variable for one-vs-rest ROC plotting
y_bin = label_binarize(y_test, classes=log_model.classes_)
n_classes = y_bin.shape[1]

# Predict probabilities for each class
y_score = log_model.predict_proba(X_test)

# Plot ROC curve for each class
plt.figure(figsize=(10, 8))
colors = cycle(['blue', 'red', 'green', 'purple', 'orange'])

for i, color in zip(range(n_classes), colors):
    RocCurveDisplay.from_predictions(y_bin[:, i], y_score[:, i],
                                     name=f'ROC curve of class {log_model.classes_[i]}',
                                     color=color,
                                     ax=plt.gca())

plt.plot([0, 1], [0, 1], 'k--', lw=2, label='Chance level')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Multiclass Classification (One-vs-Rest)', fontsize=16)
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %%
#Affichage de l'histogramme des probabilités des classes prédites
y_proba = log_model.predict_proba(X_test)

plt.hist(y_proba.max(axis=1))
plt.title("Distribution des probabilités de prédiction")
plt.xlabel("Probabilité max")
plt.ylabel("Nombre d'échantillons")
plt.show()

# %%
#Importance des features


coef_df = pd.DataFrame(log_model.coef_.T,
                       columns=log_model.classes_,
                       index=features)

coef_df
# Out:
#                             Hernia    Normal  Spondylolisthesis
# pelvic_incidence          0.085526 -0.119942           0.034416
# pelvic_tilt              -0.012222  0.032089          -0.019867
# lumbar_lordosis_angle    -0.025516  0.044597          -0.019082
# sacral_slope             -0.157774  0.105507           0.052267
# pelvic_radius             0.029618  0.017723          -0.047341
# degree_spondylolisthesis -0.073350 -0.131815           0.205165

# %%
coef_df.plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: >

# %%
#Visualisation 2D avec PCA pour visualiser séparation des classes dans l'espace des features

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

plt.figure(figsize=(8,6))
scatter = plt.scatter(X_pca[:,0], X_pca[:,1], c=df2['class'].astype('category').cat.codes)

plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.title("Projection PCA des données")

class_labels = df2['class'].astype('category').cat.categories.tolist() # Convert Index to list
plt.legend(handles=scatter.legend_elements()[0], labels=class_labels, title="Classes")

plt.show()

# %% [markdown]
# # Random Forest

# %% [markdown]
# On teste le modèle de random forest. On utilise ce modèle car il est adapté pour les mesures non linéaires, or dans notre cas les mesures ne se combinent pas de manière strictement linéaire. Il y a des relations observables mais les ratios ne sont pas identiques d'un patient à l'autre. De plus le random forest est moins sensibles aux valeurs extrêmes (comme c'est le cas pour certaines mesures dans la database) que d'autres modèles.

# %% [markdown]
# On reprend X_train et y_train qui sont les sets séparés pour l'entraînement.

# %%
# Création du modèle
rf_model = RandomForestClassifier(
    n_estimators=100,   # nombre d'arbres
    max_depth=None,     # profondeur des arbres
    random_state=42
)

# Entraînement
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
predictions_rf = rf_model.predict(X_test)

# %%
y_test.values
# Out:
# array(['Spondylolisthesis', 'Normal', 'Spondylolisthesis', 'Hernia',
#        'Hernia', 'Hernia', 'Spondylolisthesis', 'Hernia', 'Normal',
#        'Normal', 'Spondylolisthesis', 'Normal', 'Spondylolisthesis',
#        'Spondylolisthesis', 'Normal', 'Normal', 'Spondylolisthesis',
#        'Hernia', 'Spondylolisthesis', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Spondylolisthesis', 'Normal', 'Hernia',
#        'Spondylolisthesis', 'Hernia', 'Spondylolisthesis',
#        'Spondylolisthesis', 'Spondylolisthesis', 'Spondylolisthesis',
#        'Spondylolisthesis', 'Normal', 'Spondylolisthesis', 'Normal',
#        'Spondylolisthesis', 'Normal', 'Spondylolisthesis', 'Normal',
#        'Normal', 'Spondylolisthesis', 'Normal', 'Spondylolisthesis',
#        'Spondylolisthesis', 'Normal', 'Hernia', 'Spondylolisthesis',
#        'Spondylolisthesis', 'Spondylolisthesis', 'Spondylolisthesis',
#        'Normal', 'Spondylolisthesis', 'Spondylolisthesis', 'Hernia',
#        'Normal', 'Spondylolisthesis', 'Spondylolisthesis',
#        'Spondylolisthesis', 'Normal', 'Normal', 'Normal'], dtype=object)

# %% [markdown]
# On affiche un arbre du random forest pour comprendre la logique de décision du modèle.

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Choisir le premier arbre du Random Forest
estimator = rf_model.estimators_[0]

plt.figure(figsize=(20,10))
plot_tree(
    estimator,
    feature_names=features,
    class_names=['Normal','Hernia','Spondylolisthesis'],
    filled=True,
    rounded=True,
    fontsize=10
)
plt.show()

# %% [markdown]
# Malheuresement, le problème de l'arbre généré par le random forest est que comme il est profond il devient assez vite illisible.

# %% [markdown]
# On va donc faire la matrice de confusion pour pouvoir visualiser la précision du modèle. On le fait également sous forme de graphique pour faciliter la visualisation.

# %%
confusion_matrix(y_test, predictions_rf)
# Out:
# array([[ 6,  3,  0],
#        [ 2, 18,  3],
#        [ 0,  0, 30]])

# %%
#Matrice de confusion
ConfusionMatrixDisplay.from_predictions(y_test, predictions_rf,
                                        display_labels=log_model.classes_,
                                        cmap='Blues',
                                        colorbar=True)

# %% [markdown]
# On normalise la matrice de confusion. On met les valeur sur une échelle allant de 0 à 1, plus c'est proche de 1, plus la précision du modèle pour ce cas de figure est grande.

# %%
#Matrice de confusion normalisée
ConfusionMatrixDisplay.from_predictions(y_test, predictions_rf, cmap='Blues', normalize='true')

# %% [markdown]
# On observe qu tout les cas de spondylolisthesis ont été classés correctement, mais que seul les 2/3 des hernies ont bienété classées et 1/4 des personnes en bonne santé ont été classées comme étant atteint de pathologie.

# %%
accuracy_score(y_test, predictions_rf)
# Out:
# 0.8709677419354839

# %% [markdown]
# On peut observer que le modèle à une bonne précision (presque 0.9). On peut considérer que c'est satisfaisant.

# %% [markdown]
# ## Evaluation du modèle

# %%
#Evaluation des métriques
print(classification_report(y_test, predictions_rf))
# Out:
#                    precision    recall  f1-score   support
#
#            Hernia       0.75      0.67      0.71         9
#            Normal       0.86      0.78      0.82        23
# Spondylolisthesis       0.91      1.00      0.95        30
#
#          accuracy                           0.87        62
#         macro avg       0.84      0.82      0.83        62
#      weighted avg       0.87      0.87      0.87        62

# %% [markdown]
# On voit que la précision ne descend pas en dessous de 0.75 (première colonne).

# %%
#Affichage de l'histogramme des probabilités des classes prédites
y_proba = rf_model.predict_proba(X_test)

plt.hist(y_proba.max(axis=1))
plt.title("Distribution des probabilités de prédiction")
plt.xlabel("Probabilité max")
plt.ylabel("Nombre d'échantillons")
plt.show()

# %% [markdown]
# Ce graphique montre que le nombre d'échantillons augmentent plus la probabilité s'approche de 1.

# %%
# Importance des features
feat_importances = pd.DataFrame({
    'feature': features,
    'importance': rf_model.feature_importances_
}).sort_values(by='importance', ascending=False)

feat_importances
# Out:
#                     feature  importance
# 5  degree_spondylolisthesis    0.397679
# 3              sacral_slope    0.153232
# 0          pelvic_incidence    0.127925
# 2     lumbar_lordosis_angle    0.123275
# 4             pelvic_radius    0.114358
# 1               pelvic_tilt    0.083532

# %% [markdown]
# On peut observer que le paramètre le plus important est le degrée de spondylolisthesis, ce qui est logique car c'est le paramètre principal qui différencie une personne saine ou atteinte d'hernie d'une personne atteinte de spondylolisthesis.

# %% [markdown]
# Nous n'avons pas fait de ROC car ce n'est pas adapté au random forest.

# %% [markdown]
# # Tout ce qui suit sont des tests :

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

pipe = Pipeline([('scaler', StandardScaler()),('clf', LogisticRegression(max_iter=1000, random_state=23))])

# %%
from sklearn.model_selection import StratifiedKFold
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=23)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'clf__C': [0.01, 0.1, 1, 10]}
gs = GridSearchCV(pipe, param_grid, cv=cv, scoring='f1_macro', n_jobs=-1)
gs.fit(X_train, y_train)
print(gs.best_params_, gs.best_score_)
# Out:
# {'clf__C': 10} 0.8045298278176862

# %%
y.value_counts()
# Out:
# class
# Spondylolisthesis    150
# Normal               100
# Hernia                60
# Name: count, dtype: int64

# %%
LogisticRegression(class_weight='balanced', max_iter=1000)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_auc_score

y_bin = label_binarize(y_test, classes=log_model.classes_)
y_proba = log_model.predict_proba(X_test)
roc_auc_score(y_bin, y_proba, average='macro', multi_class='ovr')
# Out:
# np.float64(0.948932047542589)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

pipelines = {
  'logreg': Pipeline([('scaler', StandardScaler()), ('clf', LogisticRegression(max_iter=1000))]),
  'rf': Pipeline([('scaler', StandardScaler()), ('clf', RandomForestClassifier(random_state=23))]),
  'svc': Pipeline([('scaler', StandardScaler()), ('clf', SVC(probability=True, random_state=23))])
}

param_grids = {
  'logreg': {'clf__C':[0.01,0.1,1,10], 'clf__class_weight':[None,'balanced']},
  'rf': {'clf__n_estimators':[100,300], 'clf__max_depth':[None,10,20]},
  'svc': {'clf__C':[0.1,1,10], 'clf__kernel':['rbf','linear']}
}

from sklearn.model_selection import StratifiedKFold
cv = StratifiedKFold(5, shuffle=True, random_state=23)

results = {}
for name in pipelines:
    gs = GridSearchCV(pipelines[name], param_grids[name], cv=cv, scoring='f1_macro', n_jobs=-1)
    gs.fit(X_train, y_train)
    results[name] = gs
    print(name, gs.best_score_, gs.best_params_)
# Out:
# logreg 0.8233929154938927 {'clf__C': 1, 'clf__class_weight': 'balanced'}
# rf 0.7695713243755884 {'clf__max_depth': 10, 'clf__n_estimators': 100}
# svc 0.8135588277826946 {'clf__C': 0.1, 'clf__kernel': 'linear'}

# %%
##############################################
# 1. Préparation des données
##############################################

from sklearn.model_selection import train_test_split

import random

# Générer un entier aléatoire entre min_val et max_val (inclus)
seed = random.randint(0, 200)

# Train/Validation/Test stratifié
X_trainval, X_test, y_trainval, y_test = train_test_split(
    X, y, test_size=0.2, random_state=seed, stratify=y)

X_train, X_val, y_train, y_val = train_test_split(
    X_trainval, y_trainval, test_size=0.2, random_state=seed, stratify=y_trainval)

print("Train:", X_train.shape)
print("Val:", X_val.shape)
print("Test:", X_test.shape)


##############################################
# 2. Pipelines pour 3 modèles
##############################################

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

pipelines = {
    'logreg': Pipeline([
        ('scaler', StandardScaler()),
        ('clf', LogisticRegression(max_iter=2000))
    ]),

    'rf': Pipeline([
        ('scaler', StandardScaler()),
        ('clf', RandomForestClassifier(random_state=seed))
    ]),

    'svc': Pipeline([
        ('scaler', StandardScaler()),
        ('clf', SVC(probability=True, random_state=seed))
    ])
}


##############################################
# 3. Hyperparamètres à tester
##############################################

param_grids = {
    'logreg': {
        'clf__C': [0.01, 0.1, 1, 10],
        'clf__class_weight': [None, 'balanced']
    },

    'rf': {
        'clf__n_estimators': [200, 400],
        'clf__max_depth': [None, 10, 20]
    },

    'svc': {
        'clf__C': [0.1, 1, 10],
        'clf__kernel': ['rbf', 'linear']
    }
}


##############################################
# 4. GridSearchCV (CV stratifiée)
##############################################

from sklearn.model_selection import GridSearchCV, StratifiedKFold
cv = StratifiedKFold(5, shuffle=True, random_state=23)

results = {}

for name in pipelines:
    print(f"\n🔍 Recherche pour : {name}")
    gs = GridSearchCV(
        estimator=pipelines[name],
        param_grid=param_grids[name],
        cv=cv,
        scoring='f1_macro',
        n_jobs=-1
    )

    gs.fit(X_train, y_train)
    results[name] = gs

    print("Meilleurs paramètres :", gs.best_params_)
    print("Score CV (F1-macro) :", gs.best_score_)


##############################################
# 5. Sélection du meilleur modèle
##############################################

best_model_name = max(results, key=lambda x: results[x].best_score_)
best_model = results[best_model_name].best_estimator_

print("\n🏆 Meilleur modèle :", best_model_name)


##############################################
# 6. Évaluation sur le test set
##############################################

from sklearn.metrics import classification_report, accuracy_score

pred_test = best_model.predict(X_test)

print("\n🔎 Classification report :")
print(classification_report(y_test, pred_test))

print("✔️ Accuracy :", accuracy_score(y_test, pred_test))


##############################################
# 7. Matrice de confusion (normalisée)
##############################################

from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_predictions(
    y_test, pred_test, cmap='Blues', normalize='true'
)

ConfusionMatrixDisplay.from_predictions(
    y_test, pred_test, cmap='Blues'
)


##############################################
# 8. ROC-AUC multiclasses
##############################################

import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc

y_bin = label_binarize(y_test, classes=best_model.named_steps['clf'].classes_)
proba = best_model.predict_proba(X_test)

plt.figure(figsize=(8,6))

for i, cls in enumerate(best_model.named_steps['clf'].classes_):
    fpr, tpr, _ = roc_curve(y_bin[:, i], proba[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{cls} (AUC = {roc_auc:.2f})")

plt.plot([0,1], [0,1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Courbes ROC multiclasses")
plt.legend()
plt.show()


##############################################
# 9. Importance des features (selon le modèle)
##############################################

import numpy as np
import pandas as pd

if best_model_name == "rf":
    importances = best_model.named_steps['clf'].feature_importances_

elif best_model_name == "logreg":
    importances = np.mean(abs(best_model.named_steps['clf'].coef_), axis=0)

elif best_model_name == "svc":
    importances = abs(best_model.named_steps['clf'].coef_[0]) if best_model.named_steps['clf'].kernel=='linear' else None

if importances is not None:
    fi = pd.DataFrame({
        'feature': X.columns,
        'importance': importances
    }).sort_values(by='importance', ascending=False)

    print("\n📊 Importance des features :\n")
    print(fi)

    fi.plot(kind='barh', x='feature', figsize=(8,5), title="Feature importance")
# Out:
# Train: (198, 6)
# Val: (50, 6)
# Test: (62, 6)
#
# 🔍 Recherche pour : logreg
# Meilleurs paramètres : {'clf__C': 10, 'clf__class_weight': None}
# Score CV (F1-macro) : 0.8247323650444554
#
# 🔍 Recherche pour : rf
# Meilleurs paramètres : {'clf__max_depth': None, 'clf__n_estimators': 400}
# Score CV (F1-macro) : 0.8105273154395961
#
# 🔍 Recherche pour : svc
# Meilleurs paramètres : {'clf__C': 10, 'clf__kernel': 'rbf'}
# Score CV (F1-macro) : 0.8185602021599465
#
# 🏆 Meilleur modèle : logreg
#
# 🔎 Classification report :
#                    precision    recall  f1-score   support
#
#            Hernia       0.69      0.75      0.72        12
#            Normal       0.84      0.80      0.82        20
# Spondylolisthesis       0.97      0.97      0.97        30
#
#          accuracy                           0.87        62
#         macro avg       0.83      0.84      0.84        62
#      weighted avg       0.87      0.87      0.87        62
#
# ✔️ Accuracy : 0.8709677419354839
# 📊 Importance des features :
#
#                     feature  importance
# 5  degree_spondylolisthesis    3.745645
# 3              sacral_slope    1.563105
# 0          pelvic_incidence    1.056331
# 4             pelvic_radius    0.734412
# 1               pelvic_tilt    0.371307
# 2     lumbar_lordosis_angle    0.283765
